# %%
import mne
import numpy as np
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
import os
from pathlib import Path
import random
import joblib 
import optuna

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils.data import Dataset, DataLoader

from scipy.spatial import Delaunay
from scipy.interpolate import LinearNDInterpolator

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import GroupKFold

import warnings
warnings.filterwarnings('ignore')

# %%
SEED = 3126
EPOCHS = 40
EARLY_STOPPING_PATIENCE = 20

TIME_WINDOW = (0.1,0.5)
GRID_SIZE = 32
N_TIME_SLICES = 16
LEARNING_RATE = 7.5e-4
WEIGHT_DECAY = .001

# %%
def set_seed(seed):
    random.seed(seed)               
    np.random.seed(seed)            
    torch.manual_seed(seed)         
    torch.cuda.manual_seed(seed)    
    torch.cuda.manual_seed_all(seed) 

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def worker_init_fn(worker_id):
    np.random.seed(SEED + worker_id)
    random.seed(SEED + worker_id)

set_seed(SEED)

# %%
class MEGDataset(Dataset):
    """
    Efficient MEG → 2D Topographic Image Dataset
    Uses precomputed Delaunay triangulation + LinearNDInterpolator for fast interpolation.
    """

    def __init__(self, X, y, epochs, scaler=None,
                 time_window=TIME_WINDOW, grid_size=GRID_SIZE, n_time_slices=N_TIME_SLICES):

        self.X = X
        self.y = y
        self.times = epochs.times
        self.info  = epochs.info
        self.grid_size = grid_size
        self.n_time_slices = n_time_slices

        ## Scale channels in data
        if scaler is None:
            ch_median = np.median(X, axis=(0,2))
            ch_iqr    = np.subtract(*np.percentile(X, [75, 25], axis=(0,2))) + 1e-6
            self.scaler   = (ch_median, ch_iqr)
        else: self.scaler = scaler
        ch_median, ch_iqr = self.scaler
        self.X = (self.X - ch_median[None,:,None]) / ch_iqr[None,:,None]

        # Find time window
        t0, t1 = time_window
        start = np.argmin(np.abs(self.times - t0))
        end   = np.argmin(np.abs(self.times - t1))
        self.slice_times = np.linspace(start, end-1, n_time_slices).astype(int)
        # Get sensor positions in 2D
        positions_3d = np.array([ch['loc'][:3] for ch in self.info['chs']])
        self.pos2d   = positions_3d[:, :2]

        # Get grid coordinates
        gx = np.linspace(self.pos2d[:,0].min(), self.pos2d[:,0].max(), grid_size)
        gy = np.linspace(self.pos2d[:,1].min(), self.pos2d[:,1].max(), grid_size)
        grid_x, grid_y = np.meshgrid(gx, gy)
        self.grid_points = np.c_[grid_x.ravel(), grid_y.ravel()].copy(order='C')
        # Gets triangulation
        self.triangulation = Delaunay(self.pos2d)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        trial = self.X[idx]     # shape: (channels, time)
        label = self.y[idx]
        topo_imgs = []

        # interpolation of each time slice
        for t in self.slice_times:
            channels = trial[:, t]  # (C,)
            fill_val = np.median(channels)
            interpolator = LinearNDInterpolator(self.triangulation, channels, fill_value=fill_val)
            topo_img = interpolator(self.grid_points).reshape(self.grid_size, self.grid_size)
            # topo_img = (topo_img - topo_img.mean(axis=0))/(topo_img.std(axis=0) + 1e-6)
            topo_imgs.append(np.nan_to_num(topo_img))

        topo_imgs = np.stack(topo_imgs, axis=0)  # (n_time_slices, grid_size, grid_size)
        return torch.tensor(topo_imgs, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
# X, y, groups, first_epochs, _ = load_all_subjects_data("/kaggle/input/the-imagine-decoding-challenge/train/train", False, "localizer")
# data = MEGDataset(X,y,first_epochs)
# sample,_ = data[0]

# for k in range(N_TIME_SLICES):
#     sea.heatmap(sample[k])
#     # sea.heatmap((sample[k]-sample[k].mean(axis=0))/(sample[k].std(axis=0) + 1e-6))
#     plt.show()

# %%
class Model(nn.Module):
    def __init__(self, in_channels=N_TIME_SLICES, hidden_channels=32, dropout_p=.2, n_classes=10):
        super(Model, self).__init__()
        

        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
                nn.BatchNorm2d(out_channels),
                nn.ReLU())
            
        def linear_block(in_dim, out_dim):
            return nn.Sequential(
                nn.Linear(in_dim, out_dim, bias=False),
                nn.BatchNorm1d(out_dim),
                nn.ReLU(),
                nn.Dropout(dropout_p))
            
        self.conv = nn.Sequential(
            conv_block(in_channels, hidden_channels),
            conv_block(hidden_channels, 2*hidden_channels),
            nn.MaxPool2d(2),
            conv_block(2*hidden_channels, 3*hidden_channels),
            nn.MaxPool2d(2)
        )

        self.global_pool = nn.AdaptiveAvgPool2d(1)
            
        self.classifier = nn.Sequential(
            linear_block(3*hidden_channels, 256),
            linear_block(256, 64),
            nn.Linear(64, n_classes)
        )
        
    def forward(self, x):
        o = self.conv(x)
        o = self.global_pool(o)  # shape → (batch, channels, 1)
        o = o.view(o.size(0), -1)   # shape → (batch, channels)
        return self.classifier(o)

# %%
def init_model_weights(model):
    for module in model.modules():
        ## Linear and Convolution 
        if isinstance(module, (nn.Linear, nn.Conv2d)):
            nn.init.kaiming_uniform_(module.weight, mode="fan_in", nonlinearity="relu")
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        ## Batchnorm 
        if isinstance(module, (nn.BatchNorm2d, nn.BatchNorm1d)):
            nn.init.ones_(module.weight)
            nn.init.zeros_(module.bias)

# %%
def train_evaluate(model, train_loader, val_loader, save_path, lr, weight_decay, 
                   epochs=EPOCHS, early_stopping_patience=EARLY_STOPPING_PATIENCE, device="cuda"):
    model.to(device)
    optimizer    = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn      = nn.CrossEntropyLoss()
    lr_scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=len(train_loader))
    history = {"train_losses":[], "val_losses":[], "train_accs":[], "val_accs":[]}

    min_change          = .002
    best_val_acc        = 0.0
    epochs_not_improved = 0
    
    for epoch in range(epochs):
        # -------------------- Model training -------------------- 
        model.train()
        train_loss = 0.0
        train_acc  = 0.0
        total      = 0.0
        for X, y in train_loader:
            X, y   = X.to(device), y.to(device)
            logits = model(X)
            loss   = loss_fn(logits, y)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            
            ## Accumulates loss and accuracy
            train_loss += loss.item()
            preds       = logits.argmax(dim=1)
            train_acc  += (preds==y).sum().item()
            total      += y.size(0)
        train_loss /= len(train_loader)
        train_acc  /= total
        
        # -------------------- Model Validation -------------------- 
        model.eval()
        val_loss = 0.0
        val_acc  = 0.0
        total    = 0.0
        with torch.inference_mode():
            for X, y in val_loader:
                X, y  = X.to(device), y.to(device)

                ## Compute loss
                logits    = model(X)
                loss      = loss_fn(logits, y)
                val_loss += loss.item()
                ## Tracks validation accuracy
                preds    = logits.argmax(dim=1)
                val_acc += (preds==y).sum().item()
                total   += y.size(0)
        val_loss /= len(val_loader)
        val_acc  /= total

        ## -------------------- Logging -------------------- 
        history["train_losses"].append(train_loss)
        history["val_losses"].append(val_loss)
        history["train_accs"].append(train_acc)
        history["val_accs"].append(val_acc)
        
        print(f"Epoch {epoch+1}/{epochs} | ",
              f"Train Loss: {train_loss:.4f} | ",
              f"Val Loss: {val_loss:.4f} | ",
              f"Train Acc: {train_acc:.3f} | ",
              f"Val Acc: {val_acc:.3f}")

        # ----------------- Early Stopping -----------------
        if val_acc - best_val_acc >= min_change:
            best_val_acc        = val_acc
            epochs_not_improved = 0
            torch.save(model.state_dict(), save_path)
        else:
            epochs_not_improved += 1
            print(f"Early Stopping Counter: {epochs_not_improved}/{early_stopping_patience}")
        if epochs_not_improved >= early_stopping_patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break
    return history


def predict(model, loader, device="cuda"):
    model.eval()
    all_preds = []
    with torch.inference_mode():
        for X,_ in loader:
            X = X.to(device)
            all_preds.append(model(X).argmax(dim=1))
    return torch.cat(all_preds).cpu().numpy()

# %%
def load_subject_data(data_path, subject_id, need_label_map=True, data_type='localizer'):
    """
    Load data for a single subject.
    Returns:
        X: ndarray (M_trials, C_channels, T_timepoints)
        y: labels  (M_trials,)
        epochs: MNE epochs object
        label_map: dict mapping event names to codes
    """
    file_path = Path(data_path) / subject_id / f"{subject_id}_{data_type}-epo.fif"
    epochs    = mne.read_epochs(file_path, preload=True, verbose=False)
    X         = epochs.get_data()
    y         = epochs.events[:,2]-1  # ranges from [1, 10], subtracts 1 to become [0,9]
    label_map = None
    if need_label_map: 
        label_map = {key:value-1 for key,value in epochs.event_id.items()} # shift values down to be in range [0,9]
    return X, y, epochs, label_map



def load_all_subjects_data(data_path, need_label_map=True, data_type='localizer'):
    """
    Load data for all subjects.
    Returns:
        X: ndarray (M_trials * num_subjects, C_channels, T_timepoints)
        y: labels  (M_trials * num_subjects,)
        groups: ndarray
        label_map: dict
    """
    subject_ids = os.listdir(data_path)
    all_X, all_y, all_groups, first_epochs = [], [], [], None
    
    for idx, subject_id in enumerate(subject_ids):
        X, y, epochs, label_map = load_subject_data(data_path, subject_id, need_label_map, data_type)
        if first_epochs is None: first_epochs=epochs
        all_X.append(X)
        all_y.append(y)
        all_groups.append(np.full(len(y), idx))
    
    X = np.concatenate(all_X, axis=0) 
    y = np.concatenate(all_y, axis=0) 
    groups = np.concatenate(all_groups, axis=0)
    return X, y, groups, first_epochs, label_map

# %%
def cross_validate(data_path, n_splits=5, 
                   dataset_params=None, model_params=None, training_params=None, device='cuda'):
    # LOAD ALL SUBJECTS
    X, y, groups, first_epochs, _ = load_all_subjects_data(data_path, False, "localizer")
    print(f"Total trials: {len(y)} | Subjects: {len(os.listdir(data_path))} | X dimension: {X.shape}")
    
    # --- GroupKFold CV ---
    gkf = GroupKFold(n_splits=n_splits)
    fold_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(gkf.split(X, y, groups)):
        print(f"\nFold {fold_idx+1}/{n_splits}")

        ## Create train and validation datasets and loaders
        X_train, y_train = X[train_idx], y[train_idx]
        X_val,   y_val   = X[val_idx],   y[val_idx]
        train_data   = MEGDataset(X_train, y_train, first_epochs, **dataset_params)
        val_data     = MEGDataset(X_val, y_val, first_epochs, train_data.scaler, **dataset_params)
        train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=4, worker_init_fn=worker_init_fn)
        val_loader   = DataLoader(val_data,   batch_size=32, shuffle=False, num_workers=4, worker_init_fn=worker_init_fn)

        ## Trains model
        save_path = f"/kaggle/working/best_model_fold_{fold_idx+1}.pth"
        model     = Model(**model_params).to(device)
        init_model_weights(model)
        history   = train_evaluate(model, train_loader, val_loader, save_path, **training_params, device=device)
        
        # Evaluates model
        model = Model(**model_params).to(device)
        model.load_state_dict(torch.load(save_path))
        val_preds = predict(model, val_loader, device=device)
        val_acc   = (val_preds==y_val).mean()
        fold_scores.append(val_acc)
        print(f"Fold {fold_idx+1} Validation Accuracy: {val_acc:.4f}\n\n")
    
    mean_acc, std_acc = np.mean(fold_scores), np.std(fold_scores)
    print(f"\nMean Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_scores, mean_acc, std_acc

# %%
dataset_params  = {'time_window':TIME_WINDOW, 'grid_size':GRID_SIZE, 'n_time_slices':N_TIME_SLICES}
model_params    = {'in_channels':N_TIME_SLICES, 'n_classes':10}
training_params = {'epochs':EPOCHS, 'lr':LEARNING_RATE, "weight_decay":WEIGHT_DECAY}

# Cross-validation
cv_scores, mean_acc, std_acc = cross_validate(
    '/kaggle/input/the-imagine-decoding-challenge/train/train', 
    n_splits=15, 
    dataset_params=dataset_params,
    model_params=model_params,
    training_params=training_params,
    device='cuda'
)

# # Train on all & predict test
# # submission = train_and_predict(
# #     '/kaggle/input/the-imagine-decoding-challenge/train/train', 
# #     '/kaggle/input/the-imagine-decoding-challenge/test/test', 
# #     dataset_params=dataset_params,
# #     model_params=model_params,
# #     training_params=training_params,
# #     output_file='submission.csv',
# #     device='cpu'
# # )
# Out:
# Total trials: 7200 | Subjects: 15 | X dimension: (7200, 309, 121)
#
# Fold 1/15
# Epoch 1/40 |  Train Loss: 2.4960 |  Val Loss: 2.3122 |  Train Acc: 0.103 |  Val Acc: 0.115
# Epoch 2/40 |  Train Loss: 2.4097 |  Val Loss: 2.3235 |  Train Acc: 0.106 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3795 |  Val Loss: 2.3127 |  Train Acc: 0.102 |  Val Acc: 0.098
# Early Stopping Counter: 2/20
# Epoch 4/40 |  Train Loss: 2.3678 |  Val Loss: 2.3097 |  Train Acc: 0.110 |  Val Acc: 0.090
# Early Stopping Counter: 3/20
# Epoch 5/40 |  Train Loss: 2.3522 |  Val Loss: 2.3109 |  Train Acc: 0.108 |  Val Acc: 0.102
# Early Stopping Counter: 4/20
# Epoch 6/40 |  Train Loss: 2.3406 |  Val Loss: 2.3041 |  Train Acc: 0.112 |  Val Acc: 0.087
# Early Stopping Counter: 5/20
# Epoch 7/40 |  Train Loss: 2.3347 |  Val Loss: 2.3061 |  Train Acc: 0.113 |  Val Acc: 0.106
# Early Stopping Counter: 6/20
# Epoch 8/40 |  Train Loss: 2.3430 |  Val Loss: 2.3121 |  Train Acc: 0.111 |  Val Acc: 0.121
# Epoch 9/40 |  Train Loss: 2.3258 |  Val Loss: 2.3151 |  Train Acc: 0.121 |  Val Acc: 0.133
# Epoch 10/40 |  Train Loss: 2.3234 |  Val Loss: 2.3052 |  Train Acc: 0.117 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 11/40 |  Train Loss: 2.3274 |  Val Loss: 2.3017 |  Train Acc: 0.113 |  Val Acc: 0.108
# Early Stopping Counter: 2/20
# Epoch 12/40 |  Train Loss: 2.3268 |  Val Loss: 2.3049 |  Train Acc: 0.114 |  Val Acc: 0.131
# Early Stopping Counter: 3/20
# Epoch 13/40 |  Train Loss: 2.3158 |  Val Loss: 2.3103 |  Train Acc: 0.120 |  Val Acc: 0.108
# Early Stopping Counter: 4/20
# Epoch 14/40 |  Train Loss: 2.3128 |  Val Loss: 2.2940 |  Train Acc: 0.119 |  Val Acc: 0.138
# Epoch 15/40 |  Train Loss: 2.3183 |  Val Loss: 2.2999 |  Train Acc: 0.126 |  Val Acc: 0.090
# Early Stopping Counter: 1/20
# Epoch 16/40 |  Train Loss: 2.3141 |  Val Loss: 2.2943 |  Train Acc: 0.120 |  Val Acc: 0.096
# Early Stopping Counter: 2/20
# Epoch 17/40 |  Train Loss: 2.3052 |  Val Loss: 2.2929 |  Train Acc: 0.125 |  Val Acc: 0.100
# Early Stopping Counter: 3/20
# Epoch 18/40 |  Train Loss: 2.3147 |  Val Loss: 2.2889 |  Train Acc: 0.121 |  Val Acc: 0.110
# Early Stopping Counter: 4/20
# Epoch 19/40 |  Train Loss: 2.3107 |  Val Loss: 2.2999 |  Train Acc: 0.124 |  Val Acc: 0.117
# Early Stopping Counter: 5/20
# Epoch 20/40 |  Train Loss: 2.3046 |  Val Loss: 2.2997 |  Train Acc: 0.129 |  Val Acc: 0.129
# Early Stopping Counter: 6/20
# Epoch 21/40 |  Train Loss: 2.2989 |  Val Loss: 2.2847 |  Train Acc: 0.130 |  Val Acc: 0.138
# Early Stopping Counter: 7/20
# Epoch 22/40 |  Train Loss: 2.2971 |  Val Loss: 2.2904 |  Train Acc: 0.130 |  Val Acc: 0.125
# Early Stopping Counter: 8/20
# Epoch 23/40 |  Train Loss: 2.2926 |  Val Loss: 2.2828 |  Train Acc: 0.138 |  Val Acc: 0.154
# Epoch 24/40 |  Train Loss: 2.2967 |  Val Loss: 2.2875 |  Train Acc: 0.132 |  Val Acc: 0.113
# Early Stopping Counter: 1/20
# Epoch 25/40 |  Train Loss: 2.2828 |  Val Loss: 2.2930 |  Train Acc: 0.149 |  Val Acc: 0.104
# Early Stopping Counter: 2/20
# Epoch 26/40 |  Train Loss: 2.2854 |  Val Loss: 2.2803 |  Train Acc: 0.140 |  Val Acc: 0.110
# Early Stopping Counter: 3/20
# Epoch 27/40 |  Train Loss: 2.2822 |  Val Loss: 2.2874 |  Train Acc: 0.134 |  Val Acc: 0.135
# Early Stopping Counter: 4/20
# Epoch 28/40 |  Train Loss: 2.2824 |  Val Loss: 2.2882 |  Train Acc: 0.147 |  Val Acc: 0.129
# Early Stopping Counter: 5/20
# Epoch 29/40 |  Train Loss: 2.2812 |  Val Loss: 2.2947 |  Train Acc: 0.141 |  Val Acc: 0.115
# Early Stopping Counter: 6/20
# Epoch 30/40 |  Train Loss: 2.2822 |  Val Loss: 2.3013 |  Train Acc: 0.143 |  Val Acc: 0.117
# Early Stopping Counter: 7/20
# Epoch 31/40 |  Train Loss: 2.2780 |  Val Loss: 2.2973 |  Train Acc: 0.143 |  Val Acc: 0.100
# Early Stopping Counter: 8/20
# Epoch 32/40 |  Train Loss: 2.2714 |  Val Loss: 2.3125 |  Train Acc: 0.149 |  Val Acc: 0.096
# Early Stopping Counter: 9/20
# Epoch 33/40 |  Train Loss: 2.2667 |  Val Loss: 2.2877 |  Train Acc: 0.149 |  Val Acc: 0.140
# Early Stopping Counter: 10/20
# Epoch 34/40 |  Train Loss: 2.2625 |  Val Loss: 2.3153 |  Train Acc: 0.158 |  Val Acc: 0.100
# Early Stopping Counter: 11/20
# Epoch 35/40 |  Train Loss: 2.2639 |  Val Loss: 2.2920 |  Train Acc: 0.153 |  Val Acc: 0.117
# Early Stopping Counter: 12/20
# Epoch 36/40 |  Train Loss: 2.2582 |  Val Loss: 2.3090 |  Train Acc: 0.156 |  Val Acc: 0.098
# Early Stopping Counter: 13/20
# Epoch 37/40 |  Train Loss: 2.2592 |  Val Loss: 2.3164 |  Train Acc: 0.156 |  Val Acc: 0.123
# Early Stopping Counter: 14/20
# Epoch 38/40 |  Train Loss: 2.2566 |  Val Loss: 2.3015 |  Train Acc: 0.154 |  Val Acc: 0.117
# Early Stopping Counter: 15/20
# Epoch 39/40 |  Train Loss: 2.2516 |  Val Loss: 2.3040 |  Train Acc: 0.167 |  Val Acc: 0.110
# Early Stopping Counter: 16/20
# Epoch 40/40 |  Train Loss: 2.2462 |  Val Loss: 2.2990 |  Train Acc: 0.162 |  Val Acc: 0.125
# Early Stopping Counter: 17/20
# Fold 1 Validation Accuracy: 0.1542
#
#
#
# Fold 2/15
# Epoch 1/40 |  Train Loss: 2.5130 |  Val Loss: 2.3120 |  Train Acc: 0.099 |  Val Acc: 0.108
# Epoch 2/40 |  Train Loss: 2.4144 |  Val Loss: 2.3026 |  Train Acc: 0.101 |  Val Acc: 0.098
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3775 |  Val Loss: 2.3003 |  Train Acc: 0.104 |  Val Acc: 0.115
# Epoch 4/40 |  Train Loss: 2.3647 |  Val Loss: 2.3012 |  Train Acc: 0.104 |  Val Acc: 0.106
# Early Stopping Counter: 1/20
# Epoch 5/40 |  Train Loss: 2.3482 |  Val Loss: 2.3001 |  Train Acc: 0.112 |  Val Acc: 0.100
# Early Stopping Counter: 2/20
# Epoch 6/40 |  Train Loss: 2.3420 |  Val Loss: 2.2976 |  Train Acc: 0.111 |  Val Acc: 0.113
# Early Stopping Counter: 3/20
# Epoch 7/40 |  Train Loss: 2.3383 |  Val Loss: 2.2967 |  Train Acc: 0.110 |  Val Acc: 0.127
# Epoch 8/40 |  Train Loss: 2.3325 |  Val Loss: 2.2893 |  Train Acc: 0.112 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 9/40 |  Train Loss: 2.3327 |  Val Loss: 2.2938 |  Train Acc: 0.115 |  Val Acc: 0.096
# Early Stopping Counter: 2/20
# Epoch 10/40 |  Train Loss: 2.3284 |  Val Loss: 2.2915 |  Train Acc: 0.117 |  Val Acc: 0.121
# Early Stopping Counter: 3/20
# Epoch 11/40 |  Train Loss: 2.3233 |  Val Loss: 2.2885 |  Train Acc: 0.114 |  Val Acc: 0.123
# Early Stopping Counter: 4/20
# Epoch 12/40 |  Train Loss: 2.3261 |  Val Loss: 2.2881 |  Train Acc: 0.119 |  Val Acc: 0.115
# Early Stopping Counter: 5/20
# Epoch 13/40 |  Train Loss: 2.3180 |  Val Loss: 2.2903 |  Train Acc: 0.119 |  Val Acc: 0.138
# Epoch 14/40 |  Train Loss: 2.3188 |  Val Loss: 2.2920 |  Train Acc: 0.123 |  Val Acc: 0.117
# Early Stopping Counter: 1/20
# Epoch 15/40 |  Train Loss: 2.3176 |  Val Loss: 2.2865 |  Train Acc: 0.125 |  Val Acc: 0.146
# Epoch 16/40 |  Train Loss: 2.3185 |  Val Loss: 2.2861 |  Train Acc: 0.120 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 17/40 |  Train Loss: 2.3112 |  Val Loss: 2.2892 |  Train Acc: 0.125 |  Val Acc: 0.135
# Early Stopping Counter: 2/20
# Epoch 18/40 |  Train Loss: 2.2994 |  Val Loss: 2.2828 |  Train Acc: 0.131 |  Val Acc: 0.146
# Early Stopping Counter: 3/20
# Epoch 19/40 |  Train Loss: 2.3081 |  Val Loss: 2.2835 |  Train Acc: 0.130 |  Val Acc: 0.131
# Early Stopping Counter: 4/20
# Epoch 20/40 |  Train Loss: 2.3016 |  Val Loss: 2.2888 |  Train Acc: 0.131 |  Val Acc: 0.135
# Early Stopping Counter: 5/20
# Epoch 21/40 |  Train Loss: 2.3006 |  Val Loss: 2.2859 |  Train Acc: 0.129 |  Val Acc: 0.140
# Early Stopping Counter: 6/20
# Epoch 22/40 |  Train Loss: 2.2992 |  Val Loss: 2.2858 |  Train Acc: 0.123 |  Val Acc: 0.133
# Early Stopping Counter: 7/20
# Epoch 23/40 |  Train Loss: 2.2905 |  Val Loss: 2.2801 |  Train Acc: 0.136 |  Val Acc: 0.131
# Early Stopping Counter: 8/20
# Epoch 24/40 |  Train Loss: 2.2878 |  Val Loss: 2.2829 |  Train Acc: 0.130 |  Val Acc: 0.152
# Epoch 25/40 |  Train Loss: 2.2884 |  Val Loss: 2.2907 |  Train Acc: 0.134 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 26/40 |  Train Loss: 2.2880 |  Val Loss: 2.2807 |  Train Acc: 0.142 |  Val Acc: 0.148
# Early Stopping Counter: 2/20
# Epoch 27/40 |  Train Loss: 2.2810 |  Val Loss: 2.2889 |  Train Acc: 0.143 |  Val Acc: 0.135
# Early Stopping Counter: 3/20
# Epoch 28/40 |  Train Loss: 2.2797 |  Val Loss: 2.2756 |  Train Acc: 0.143 |  Val Acc: 0.148
# Early Stopping Counter: 4/20
# Epoch 29/40 |  Train Loss: 2.2781 |  Val Loss: 2.2905 |  Train Acc: 0.143 |  Val Acc: 0.138
# Early Stopping Counter: 5/20
# Epoch 30/40 |  Train Loss: 2.2660 |  Val Loss: 2.2910 |  Train Acc: 0.146 |  Val Acc: 0.140
# Early Stopping Counter: 6/20
# Epoch 31/40 |  Train Loss: 2.2686 |  Val Loss: 2.2889 |  Train Acc: 0.146 |  Val Acc: 0.133
# Early Stopping Counter: 7/20
# Epoch 32/40 |  Train Loss: 2.2668 |  Val Loss: 2.2921 |  Train Acc: 0.150 |  Val Acc: 0.142
# Early Stopping Counter: 8/20
# Epoch 33/40 |  Train Loss: 2.2644 |  Val Loss: 2.2934 |  Train Acc: 0.151 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 34/40 |  Train Loss: 2.2521 |  Val Loss: 2.2875 |  Train Acc: 0.163 |  Val Acc: 0.144
# Early Stopping Counter: 10/20
# Epoch 35/40 |  Train Loss: 2.2540 |  Val Loss: 2.2906 |  Train Acc: 0.154 |  Val Acc: 0.127
# Early Stopping Counter: 11/20
# Epoch 36/40 |  Train Loss: 2.2515 |  Val Loss: 2.2905 |  Train Acc: 0.162 |  Val Acc: 0.148
# Early Stopping Counter: 12/20
# Epoch 37/40 |  Train Loss: 2.2515 |  Val Loss: 2.2964 |  Train Acc: 0.166 |  Val Acc: 0.110
# Early Stopping Counter: 13/20
# Epoch 38/40 |  Train Loss: 2.2446 |  Val Loss: 2.2927 |  Train Acc: 0.163 |  Val Acc: 0.113
# Early Stopping Counter: 14/20
# Epoch 39/40 |  Train Loss: 2.2393 |  Val Loss: 2.2943 |  Train Acc: 0.164 |  Val Acc: 0.117
# Early Stopping Counter: 15/20
# Epoch 40/40 |  Train Loss: 2.2339 |  Val Loss: 2.2989 |  Train Acc: 0.168 |  Val Acc: 0.117
# Early Stopping Counter: 16/20
# Fold 2 Validation Accuracy: 0.1521
#
#
#
# Fold 3/15
# Epoch 1/40 |  Train Loss: 2.4759 |  Val Loss: 2.3254 |  Train Acc: 0.103 |  Val Acc: 0.098
# Epoch 2/40 |  Train Loss: 2.4054 |  Val Loss: 2.3101 |  Train Acc: 0.095 |  Val Acc: 0.096
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3813 |  Val Loss: 2.3002 |  Train Acc: 0.097 |  Val Acc: 0.102
# Epoch 4/40 |  Train Loss: 2.3742 |  Val Loss: 2.2983 |  Train Acc: 0.101 |  Val Acc: 0.119
# Epoch 5/40 |  Train Loss: 2.3522 |  Val Loss: 2.3009 |  Train Acc: 0.106 |  Val Acc: 0.100
# Early Stopping Counter: 1/20
# Epoch 6/40 |  Train Loss: 2.3518 |  Val Loss: 2.2975 |  Train Acc: 0.107 |  Val Acc: 0.096
# Early Stopping Counter: 2/20
# Epoch 7/40 |  Train Loss: 2.3430 |  Val Loss: 2.3086 |  Train Acc: 0.116 |  Val Acc: 0.102
# Early Stopping Counter: 3/20
# Epoch 8/40 |  Train Loss: 2.3410 |  Val Loss: 2.3022 |  Train Acc: 0.113 |  Val Acc: 0.117
# Early Stopping Counter: 4/20
# Epoch 9/40 |  Train Loss: 2.3326 |  Val Loss: 2.3069 |  Train Acc: 0.114 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 10/40 |  Train Loss: 2.3292 |  Val Loss: 2.3098 |  Train Acc: 0.120 |  Val Acc: 0.100
# Early Stopping Counter: 6/20
# Epoch 11/40 |  Train Loss: 2.3265 |  Val Loss: 2.3190 |  Train Acc: 0.117 |  Val Acc: 0.100
# Early Stopping Counter: 7/20
# Epoch 12/40 |  Train Loss: 2.3297 |  Val Loss: 2.3124 |  Train Acc: 0.114 |  Val Acc: 0.117
# Early Stopping Counter: 8/20
# Epoch 13/40 |  Train Loss: 2.3182 |  Val Loss: 2.3149 |  Train Acc: 0.124 |  Val Acc: 0.117
# Early Stopping Counter: 9/20
# Epoch 14/40 |  Train Loss: 2.3219 |  Val Loss: 2.3214 |  Train Acc: 0.119 |  Val Acc: 0.125
# Epoch 15/40 |  Train Loss: 2.3138 |  Val Loss: 2.3153 |  Train Acc: 0.127 |  Val Acc: 0.090
# Early Stopping Counter: 1/20
# Epoch 16/40 |  Train Loss: 2.3207 |  Val Loss: 2.3169 |  Train Acc: 0.123 |  Val Acc: 0.098
# Early Stopping Counter: 2/20
# Epoch 17/40 |  Train Loss: 2.3006 |  Val Loss: 2.3139 |  Train Acc: 0.132 |  Val Acc: 0.094
# Early Stopping Counter: 3/20
# Epoch 18/40 |  Train Loss: 2.3046 |  Val Loss: 2.3182 |  Train Acc: 0.129 |  Val Acc: 0.085
# Early Stopping Counter: 4/20
# Epoch 19/40 |  Train Loss: 2.3027 |  Val Loss: 2.3300 |  Train Acc: 0.131 |  Val Acc: 0.081
# Early Stopping Counter: 5/20
# Epoch 20/40 |  Train Loss: 2.2954 |  Val Loss: 2.3165 |  Train Acc: 0.131 |  Val Acc: 0.090
# Early Stopping Counter: 6/20
# Epoch 21/40 |  Train Loss: 2.2964 |  Val Loss: 2.3203 |  Train Acc: 0.131 |  Val Acc: 0.096
# Early Stopping Counter: 7/20
# Epoch 22/40 |  Train Loss: 2.2924 |  Val Loss: 2.3178 |  Train Acc: 0.138 |  Val Acc: 0.100
# Early Stopping Counter: 8/20
# Epoch 23/40 |  Train Loss: 2.2919 |  Val Loss: 2.3253 |  Train Acc: 0.138 |  Val Acc: 0.092
# Early Stopping Counter: 9/20
# Epoch 24/40 |  Train Loss: 2.2799 |  Val Loss: 2.3287 |  Train Acc: 0.146 |  Val Acc: 0.100
# Early Stopping Counter: 10/20
# Epoch 25/40 |  Train Loss: 2.2866 |  Val Loss: 2.3396 |  Train Acc: 0.138 |  Val Acc: 0.104
# Early Stopping Counter: 11/20
# Epoch 26/40 |  Train Loss: 2.2763 |  Val Loss: 2.3318 |  Train Acc: 0.151 |  Val Acc: 0.096
# Early Stopping Counter: 12/20
# Epoch 27/40 |  Train Loss: 2.2741 |  Val Loss: 2.3484 |  Train Acc: 0.152 |  Val Acc: 0.098
# Early Stopping Counter: 13/20
# Epoch 28/40 |  Train Loss: 2.2789 |  Val Loss: 2.3320 |  Train Acc: 0.146 |  Val Acc: 0.090
# Early Stopping Counter: 14/20
# Epoch 29/40 |  Train Loss: 2.2679 |  Val Loss: 2.3370 |  Train Acc: 0.154 |  Val Acc: 0.085
# Early Stopping Counter: 15/20
# Epoch 30/40 |  Train Loss: 2.2646 |  Val Loss: 2.3351 |  Train Acc: 0.149 |  Val Acc: 0.096
# Early Stopping Counter: 16/20
# Epoch 31/40 |  Train Loss: 2.2630 |  Val Loss: 2.3438 |  Train Acc: 0.160 |  Val Acc: 0.104
# Early Stopping Counter: 17/20
# Epoch 32/40 |  Train Loss: 2.2682 |  Val Loss: 2.3381 |  Train Acc: 0.156 |  Val Acc: 0.110
# Early Stopping Counter: 18/20
# Epoch 33/40 |  Train Loss: 2.2613 |  Val Loss: 2.3550 |  Train Acc: 0.158 |  Val Acc: 0.094
# Early Stopping Counter: 19/20
# Epoch 34/40 |  Train Loss: 2.2553 |  Val Loss: 2.3481 |  Train Acc: 0.158 |  Val Acc: 0.123
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 34
# Fold 3 Validation Accuracy: 0.1250
#
#
#
# Fold 4/15
# Epoch 1/40 |  Train Loss: 2.4847 |  Val Loss: 2.3058 |  Train Acc: 0.104 |  Val Acc: 0.085
# Epoch 2/40 |  Train Loss: 2.4068 |  Val Loss: 2.3020 |  Train Acc: 0.105 |  Val Acc: 0.110
# Epoch 3/40 |  Train Loss: 2.3806 |  Val Loss: 2.3009 |  Train Acc: 0.101 |  Val Acc: 0.085
# Early Stopping Counter: 1/20
# Epoch 4/40 |  Train Loss: 2.3675 |  Val Loss: 2.3006 |  Train Acc: 0.104 |  Val Acc: 0.106
# Early Stopping Counter: 2/20
# Epoch 5/40 |  Train Loss: 2.3565 |  Val Loss: 2.3009 |  Train Acc: 0.107 |  Val Acc: 0.092
# Early Stopping Counter: 3/20
# Epoch 6/40 |  Train Loss: 2.3525 |  Val Loss: 2.2960 |  Train Acc: 0.110 |  Val Acc: 0.102
# Early Stopping Counter: 4/20
# Epoch 7/40 |  Train Loss: 2.3415 |  Val Loss: 2.2956 |  Train Acc: 0.110 |  Val Acc: 0.131
# Epoch 8/40 |  Train Loss: 2.3418 |  Val Loss: 2.2947 |  Train Acc: 0.114 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 9/40 |  Train Loss: 2.3294 |  Val Loss: 2.2988 |  Train Acc: 0.115 |  Val Acc: 0.100
# Early Stopping Counter: 2/20
# Epoch 10/40 |  Train Loss: 2.3388 |  Val Loss: 2.2964 |  Train Acc: 0.114 |  Val Acc: 0.104
# Early Stopping Counter: 3/20
# Epoch 11/40 |  Train Loss: 2.3252 |  Val Loss: 2.3002 |  Train Acc: 0.119 |  Val Acc: 0.092
# Early Stopping Counter: 4/20
# Epoch 12/40 |  Train Loss: 2.3227 |  Val Loss: 2.2946 |  Train Acc: 0.117 |  Val Acc: 0.113
# Early Stopping Counter: 5/20
# Epoch 13/40 |  Train Loss: 2.3204 |  Val Loss: 2.2948 |  Train Acc: 0.122 |  Val Acc: 0.123
# Early Stopping Counter: 6/20
# Epoch 14/40 |  Train Loss: 2.3157 |  Val Loss: 2.2985 |  Train Acc: 0.126 |  Val Acc: 0.090
# Early Stopping Counter: 7/20
# Epoch 15/40 |  Train Loss: 2.3119 |  Val Loss: 2.2913 |  Train Acc: 0.129 |  Val Acc: 0.106
# Early Stopping Counter: 8/20
# Epoch 16/40 |  Train Loss: 2.3079 |  Val Loss: 2.2889 |  Train Acc: 0.128 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 17/40 |  Train Loss: 2.3113 |  Val Loss: 2.2976 |  Train Acc: 0.121 |  Val Acc: 0.121
# Early Stopping Counter: 10/20
# Epoch 18/40 |  Train Loss: 2.3036 |  Val Loss: 2.2980 |  Train Acc: 0.121 |  Val Acc: 0.104
# Early Stopping Counter: 11/20
# Epoch 19/40 |  Train Loss: 2.2963 |  Val Loss: 2.2901 |  Train Acc: 0.133 |  Val Acc: 0.113
# Early Stopping Counter: 12/20
# Epoch 20/40 |  Train Loss: 2.2945 |  Val Loss: 2.2935 |  Train Acc: 0.130 |  Val Acc: 0.127
# Early Stopping Counter: 13/20
# Epoch 21/40 |  Train Loss: 2.2992 |  Val Loss: 2.2967 |  Train Acc: 0.133 |  Val Acc: 0.100
# Early Stopping Counter: 14/20
# Epoch 22/40 |  Train Loss: 2.2843 |  Val Loss: 2.2895 |  Train Acc: 0.139 |  Val Acc: 0.115
# Early Stopping Counter: 15/20
# Epoch 23/40 |  Train Loss: 2.2912 |  Val Loss: 2.2849 |  Train Acc: 0.129 |  Val Acc: 0.144
# Epoch 24/40 |  Train Loss: 2.2845 |  Val Loss: 2.2903 |  Train Acc: 0.142 |  Val Acc: 0.094
# Early Stopping Counter: 1/20
# Epoch 25/40 |  Train Loss: 2.2829 |  Val Loss: 2.2927 |  Train Acc: 0.146 |  Val Acc: 0.115
# Early Stopping Counter: 2/20
# Epoch 26/40 |  Train Loss: 2.2858 |  Val Loss: 2.2970 |  Train Acc: 0.138 |  Val Acc: 0.106
# Early Stopping Counter: 3/20
# Epoch 27/40 |  Train Loss: 2.2768 |  Val Loss: 2.2912 |  Train Acc: 0.147 |  Val Acc: 0.108
# Early Stopping Counter: 4/20
# Epoch 28/40 |  Train Loss: 2.2713 |  Val Loss: 2.2855 |  Train Acc: 0.142 |  Val Acc: 0.127
# Early Stopping Counter: 5/20
# Epoch 29/40 |  Train Loss: 2.2681 |  Val Loss: 2.2996 |  Train Acc: 0.150 |  Val Acc: 0.098
# Early Stopping Counter: 6/20
# Epoch 30/40 |  Train Loss: 2.2677 |  Val Loss: 2.2924 |  Train Acc: 0.153 |  Val Acc: 0.102
# Early Stopping Counter: 7/20
# Epoch 31/40 |  Train Loss: 2.2619 |  Val Loss: 2.2952 |  Train Acc: 0.156 |  Val Acc: 0.090
# Early Stopping Counter: 8/20
# Epoch 32/40 |  Train Loss: 2.2618 |  Val Loss: 2.2967 |  Train Acc: 0.158 |  Val Acc: 0.102
# Early Stopping Counter: 9/20
# Epoch 33/40 |  Train Loss: 2.2506 |  Val Loss: 2.2968 |  Train Acc: 0.165 |  Val Acc: 0.119
# Early Stopping Counter: 10/20
# Epoch 34/40 |  Train Loss: 2.2471 |  Val Loss: 2.3025 |  Train Acc: 0.160 |  Val Acc: 0.110
# Early Stopping Counter: 11/20
# Epoch 35/40 |  Train Loss: 2.2460 |  Val Loss: 2.2960 |  Train Acc: 0.169 |  Val Acc: 0.117
# Early Stopping Counter: 12/20
# Epoch 36/40 |  Train Loss: 2.2364 |  Val Loss: 2.2817 |  Train Acc: 0.164 |  Val Acc: 0.117
# Early Stopping Counter: 13/20
# Epoch 37/40 |  Train Loss: 2.2291 |  Val Loss: 2.2921 |  Train Acc: 0.178 |  Val Acc: 0.127
# Early Stopping Counter: 14/20
# Epoch 38/40 |  Train Loss: 2.2257 |  Val Loss: 2.2918 |  Train Acc: 0.177 |  Val Acc: 0.123
# Early Stopping Counter: 15/20
# Epoch 39/40 |  Train Loss: 2.2215 |  Val Loss: 2.3136 |  Train Acc: 0.183 |  Val Acc: 0.096
# Early Stopping Counter: 16/20
# Epoch 40/40 |  Train Loss: 2.2203 |  Val Loss: 2.3134 |  Train Acc: 0.184 |  Val Acc: 0.127
# Early Stopping Counter: 17/20
# Fold 4 Validation Accuracy: 0.1437
#
#
#
# Fold 5/15
# Epoch 1/40 |  Train Loss: 2.4945 |  Val Loss: 2.3213 |  Train Acc: 0.099 |  Val Acc: 0.092
# Epoch 2/40 |  Train Loss: 2.4010 |  Val Loss: 2.3085 |  Train Acc: 0.105 |  Val Acc: 0.110
# Epoch 3/40 |  Train Loss: 2.3750 |  Val Loss: 2.3088 |  Train Acc: 0.109 |  Val Acc: 0.087
# Early Stopping Counter: 1/20
# Epoch 4/40 |  Train Loss: 2.3584 |  Val Loss: 2.3047 |  Train Acc: 0.108 |  Val Acc: 0.090
# Early Stopping Counter: 2/20
# Epoch 5/40 |  Train Loss: 2.3584 |  Val Loss: 2.3071 |  Train Acc: 0.107 |  Val Acc: 0.110
# Early Stopping Counter: 3/20
# Epoch 6/40 |  Train Loss: 2.3525 |  Val Loss: 2.3032 |  Train Acc: 0.109 |  Val Acc: 0.127
# Epoch 7/40 |  Train Loss: 2.3337 |  Val Loss: 2.3040 |  Train Acc: 0.107 |  Val Acc: 0.133
# Epoch 8/40 |  Train Loss: 2.3296 |  Val Loss: 2.3046 |  Train Acc: 0.115 |  Val Acc: 0.125
# Early Stopping Counter: 1/20
# Epoch 9/40 |  Train Loss: 2.3340 |  Val Loss: 2.3025 |  Train Acc: 0.112 |  Val Acc: 0.121
# Early Stopping Counter: 2/20
# Epoch 10/40 |  Train Loss: 2.3227 |  Val Loss: 2.2995 |  Train Acc: 0.119 |  Val Acc: 0.102
# Early Stopping Counter: 3/20
# Epoch 11/40 |  Train Loss: 2.3130 |  Val Loss: 2.3011 |  Train Acc: 0.124 |  Val Acc: 0.106
# Early Stopping Counter: 4/20
# Epoch 12/40 |  Train Loss: 2.3156 |  Val Loss: 2.3042 |  Train Acc: 0.125 |  Val Acc: 0.098
# Early Stopping Counter: 5/20
# Epoch 13/40 |  Train Loss: 2.3114 |  Val Loss: 2.3038 |  Train Acc: 0.126 |  Val Acc: 0.104
# Early Stopping Counter: 6/20
# Epoch 14/40 |  Train Loss: 2.3047 |  Val Loss: 2.3056 |  Train Acc: 0.128 |  Val Acc: 0.098
# Early Stopping Counter: 7/20
# Epoch 15/40 |  Train Loss: 2.3018 |  Val Loss: 2.3001 |  Train Acc: 0.133 |  Val Acc: 0.117
# Early Stopping Counter: 8/20
# Epoch 16/40 |  Train Loss: 2.3077 |  Val Loss: 2.2969 |  Train Acc: 0.122 |  Val Acc: 0.108
# Early Stopping Counter: 9/20
# Epoch 17/40 |  Train Loss: 2.3056 |  Val Loss: 2.3019 |  Train Acc: 0.126 |  Val Acc: 0.108
# Early Stopping Counter: 10/20
# Epoch 18/40 |  Train Loss: 2.3039 |  Val Loss: 2.3001 |  Train Acc: 0.131 |  Val Acc: 0.100
# Early Stopping Counter: 11/20
# Epoch 19/40 |  Train Loss: 2.2946 |  Val Loss: 2.3040 |  Train Acc: 0.137 |  Val Acc: 0.102
# Early Stopping Counter: 12/20
# Epoch 20/40 |  Train Loss: 2.2929 |  Val Loss: 2.3148 |  Train Acc: 0.132 |  Val Acc: 0.102
# Early Stopping Counter: 13/20
# Epoch 21/40 |  Train Loss: 2.2870 |  Val Loss: 2.3059 |  Train Acc: 0.138 |  Val Acc: 0.115
# Early Stopping Counter: 14/20
# Epoch 22/40 |  Train Loss: 2.2841 |  Val Loss: 2.3159 |  Train Acc: 0.141 |  Val Acc: 0.117
# Early Stopping Counter: 15/20
# Epoch 23/40 |  Train Loss: 2.2833 |  Val Loss: 2.3071 |  Train Acc: 0.137 |  Val Acc: 0.117
# Early Stopping Counter: 16/20
# Epoch 24/40 |  Train Loss: 2.2839 |  Val Loss: 2.3060 |  Train Acc: 0.141 |  Val Acc: 0.094
# Early Stopping Counter: 17/20
# Epoch 25/40 |  Train Loss: 2.2825 |  Val Loss: 2.3015 |  Train Acc: 0.145 |  Val Acc: 0.123
# Early Stopping Counter: 18/20
# Epoch 26/40 |  Train Loss: 2.2791 |  Val Loss: 2.3054 |  Train Acc: 0.144 |  Val Acc: 0.100
# Early Stopping Counter: 19/20
# Epoch 27/40 |  Train Loss: 2.2726 |  Val Loss: 2.3080 |  Train Acc: 0.143 |  Val Acc: 0.106
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 27
# Fold 5 Validation Accuracy: 0.1333
#
#
#
# Fold 6/15
# Epoch 1/40 |  Train Loss: 2.4684 |  Val Loss: 2.3589 |  Train Acc: 0.095 |  Val Acc: 0.108
# Epoch 2/40 |  Train Loss: 2.3989 |  Val Loss: 2.3441 |  Train Acc: 0.101 |  Val Acc: 0.113
# Epoch 3/40 |  Train Loss: 2.3764 |  Val Loss: 2.3196 |  Train Acc: 0.105 |  Val Acc: 0.138
# Epoch 4/40 |  Train Loss: 2.3589 |  Val Loss: 2.3161 |  Train Acc: 0.112 |  Val Acc: 0.110
# Early Stopping Counter: 1/20
# Epoch 5/40 |  Train Loss: 2.3528 |  Val Loss: 2.3055 |  Train Acc: 0.104 |  Val Acc: 0.125
# Early Stopping Counter: 2/20
# Epoch 6/40 |  Train Loss: 2.3487 |  Val Loss: 2.3181 |  Train Acc: 0.112 |  Val Acc: 0.092
# Early Stopping Counter: 3/20
# Epoch 7/40 |  Train Loss: 2.3477 |  Val Loss: 2.3038 |  Train Acc: 0.110 |  Val Acc: 0.142
# Epoch 8/40 |  Train Loss: 2.3432 |  Val Loss: 2.3110 |  Train Acc: 0.106 |  Val Acc: 0.108
# Early Stopping Counter: 1/20
# Epoch 9/40 |  Train Loss: 2.3308 |  Val Loss: 2.3269 |  Train Acc: 0.114 |  Val Acc: 0.100
# Early Stopping Counter: 2/20
# Epoch 10/40 |  Train Loss: 2.3335 |  Val Loss: 2.3099 |  Train Acc: 0.122 |  Val Acc: 0.121
# Early Stopping Counter: 3/20
# Epoch 11/40 |  Train Loss: 2.3255 |  Val Loss: 2.3103 |  Train Acc: 0.120 |  Val Acc: 0.119
# Early Stopping Counter: 4/20
# Epoch 12/40 |  Train Loss: 2.3231 |  Val Loss: 2.3131 |  Train Acc: 0.123 |  Val Acc: 0.131
# Early Stopping Counter: 5/20
# Epoch 13/40 |  Train Loss: 2.3192 |  Val Loss: 2.3196 |  Train Acc: 0.125 |  Val Acc: 0.123
# Early Stopping Counter: 6/20
# Epoch 14/40 |  Train Loss: 2.3196 |  Val Loss: 2.3157 |  Train Acc: 0.116 |  Val Acc: 0.113
# Early Stopping Counter: 7/20
# Epoch 15/40 |  Train Loss: 2.3179 |  Val Loss: 2.3027 |  Train Acc: 0.124 |  Val Acc: 0.142
# Early Stopping Counter: 8/20
# Epoch 16/40 |  Train Loss: 2.3092 |  Val Loss: 2.3070 |  Train Acc: 0.122 |  Val Acc: 0.127
# Early Stopping Counter: 9/20
# Epoch 17/40 |  Train Loss: 2.3041 |  Val Loss: 2.3274 |  Train Acc: 0.124 |  Val Acc: 0.108
# Early Stopping Counter: 10/20
# Epoch 18/40 |  Train Loss: 2.2994 |  Val Loss: 2.3200 |  Train Acc: 0.137 |  Val Acc: 0.094
# Early Stopping Counter: 11/20
# Epoch 19/40 |  Train Loss: 2.3011 |  Val Loss: 2.3073 |  Train Acc: 0.134 |  Val Acc: 0.108
# Early Stopping Counter: 12/20
# Epoch 20/40 |  Train Loss: 2.2986 |  Val Loss: 2.3117 |  Train Acc: 0.136 |  Val Acc: 0.102
# Early Stopping Counter: 13/20
# Epoch 21/40 |  Train Loss: 2.2931 |  Val Loss: 2.3081 |  Train Acc: 0.139 |  Val Acc: 0.115
# Early Stopping Counter: 14/20
# Epoch 22/40 |  Train Loss: 2.2917 |  Val Loss: 2.3041 |  Train Acc: 0.144 |  Val Acc: 0.100
# Early Stopping Counter: 15/20
# Epoch 23/40 |  Train Loss: 2.2900 |  Val Loss: 2.3328 |  Train Acc: 0.132 |  Val Acc: 0.119
# Early Stopping Counter: 16/20
# Epoch 24/40 |  Train Loss: 2.2862 |  Val Loss: 2.3210 |  Train Acc: 0.135 |  Val Acc: 0.108
# Early Stopping Counter: 17/20
# Epoch 25/40 |  Train Loss: 2.2891 |  Val Loss: 2.3115 |  Train Acc: 0.143 |  Val Acc: 0.115
# Early Stopping Counter: 18/20
# Epoch 26/40 |  Train Loss: 2.2777 |  Val Loss: 2.3189 |  Train Acc: 0.145 |  Val Acc: 0.110
# Early Stopping Counter: 19/20
# Epoch 27/40 |  Train Loss: 2.2904 |  Val Loss: 2.3112 |  Train Acc: 0.134 |  Val Acc: 0.123
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 27
# Fold 6 Validation Accuracy: 0.1417
#
#
#
# Fold 7/15
# Epoch 1/40 |  Train Loss: 2.4878 |  Val Loss: 2.3794 |  Train Acc: 0.098 |  Val Acc: 0.094
# Epoch 2/40 |  Train Loss: 2.4216 |  Val Loss: 2.3360 |  Train Acc: 0.104 |  Val Acc: 0.123
# Epoch 3/40 |  Train Loss: 2.3880 |  Val Loss: 2.3285 |  Train Acc: 0.100 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 4/40 |  Train Loss: 2.3760 |  Val Loss: 2.3271 |  Train Acc: 0.106 |  Val Acc: 0.115
# Early Stopping Counter: 2/20
# Epoch 5/40 |  Train Loss: 2.3611 |  Val Loss: 2.3302 |  Train Acc: 0.112 |  Val Acc: 0.100
# Early Stopping Counter: 3/20
# Epoch 6/40 |  Train Loss: 2.3504 |  Val Loss: 2.3146 |  Train Acc: 0.107 |  Val Acc: 0.106
# Early Stopping Counter: 4/20
# Epoch 7/40 |  Train Loss: 2.3563 |  Val Loss: 2.3049 |  Train Acc: 0.114 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 8/40 |  Train Loss: 2.3489 |  Val Loss: 2.3039 |  Train Acc: 0.119 |  Val Acc: 0.108
# Early Stopping Counter: 6/20
# Epoch 9/40 |  Train Loss: 2.3398 |  Val Loss: 2.3097 |  Train Acc: 0.122 |  Val Acc: 0.106
# Early Stopping Counter: 7/20
# Epoch 10/40 |  Train Loss: 2.3396 |  Val Loss: 2.3061 |  Train Acc: 0.120 |  Val Acc: 0.121
# Early Stopping Counter: 8/20
# Epoch 11/40 |  Train Loss: 2.3362 |  Val Loss: 2.3098 |  Train Acc: 0.122 |  Val Acc: 0.121
# Early Stopping Counter: 9/20
# Epoch 12/40 |  Train Loss: 2.3317 |  Val Loss: 2.3097 |  Train Acc: 0.117 |  Val Acc: 0.115
# Early Stopping Counter: 10/20
# Epoch 13/40 |  Train Loss: 2.3261 |  Val Loss: 2.3024 |  Train Acc: 0.129 |  Val Acc: 0.117
# Early Stopping Counter: 11/20
# Epoch 14/40 |  Train Loss: 2.3161 |  Val Loss: 2.3119 |  Train Acc: 0.126 |  Val Acc: 0.104
# Early Stopping Counter: 12/20
# Epoch 15/40 |  Train Loss: 2.3154 |  Val Loss: 2.3036 |  Train Acc: 0.121 |  Val Acc: 0.108
# Early Stopping Counter: 13/20
# Epoch 16/40 |  Train Loss: 2.3072 |  Val Loss: 2.3009 |  Train Acc: 0.133 |  Val Acc: 0.113
# Early Stopping Counter: 14/20
# Epoch 17/40 |  Train Loss: 2.3079 |  Val Loss: 2.2975 |  Train Acc: 0.133 |  Val Acc: 0.108
# Early Stopping Counter: 15/20
# Epoch 18/40 |  Train Loss: 2.3106 |  Val Loss: 2.3000 |  Train Acc: 0.129 |  Val Acc: 0.100
# Early Stopping Counter: 16/20
# Epoch 19/40 |  Train Loss: 2.3068 |  Val Loss: 2.3114 |  Train Acc: 0.133 |  Val Acc: 0.117
# Early Stopping Counter: 17/20
# Epoch 20/40 |  Train Loss: 2.2995 |  Val Loss: 2.3162 |  Train Acc: 0.134 |  Val Acc: 0.094
# Early Stopping Counter: 18/20
# Epoch 21/40 |  Train Loss: 2.3005 |  Val Loss: 2.3129 |  Train Acc: 0.137 |  Val Acc: 0.133
# Epoch 22/40 |  Train Loss: 2.2974 |  Val Loss: 2.3034 |  Train Acc: 0.135 |  Val Acc: 0.102
# Early Stopping Counter: 1/20
# Epoch 23/40 |  Train Loss: 2.2995 |  Val Loss: 2.3173 |  Train Acc: 0.135 |  Val Acc: 0.113
# Early Stopping Counter: 2/20
# Epoch 24/40 |  Train Loss: 2.2947 |  Val Loss: 2.3005 |  Train Acc: 0.138 |  Val Acc: 0.125
# Early Stopping Counter: 3/20
# Epoch 25/40 |  Train Loss: 2.2914 |  Val Loss: 2.3163 |  Train Acc: 0.143 |  Val Acc: 0.121
# Early Stopping Counter: 4/20
# Epoch 26/40 |  Train Loss: 2.2843 |  Val Loss: 2.3110 |  Train Acc: 0.145 |  Val Acc: 0.135
# Epoch 27/40 |  Train Loss: 2.2815 |  Val Loss: 2.3123 |  Train Acc: 0.144 |  Val Acc: 0.115
# Early Stopping Counter: 1/20
# Epoch 28/40 |  Train Loss: 2.2834 |  Val Loss: 2.3147 |  Train Acc: 0.145 |  Val Acc: 0.098
# Early Stopping Counter: 2/20
# Epoch 29/40 |  Train Loss: 2.2786 |  Val Loss: 2.3272 |  Train Acc: 0.147 |  Val Acc: 0.115
# Early Stopping Counter: 3/20
# Epoch 30/40 |  Train Loss: 2.2787 |  Val Loss: 2.3128 |  Train Acc: 0.146 |  Val Acc: 0.098
# Early Stopping Counter: 4/20
# Epoch 31/40 |  Train Loss: 2.2747 |  Val Loss: 2.3283 |  Train Acc: 0.150 |  Val Acc: 0.104
# Early Stopping Counter: 5/20
# Epoch 32/40 |  Train Loss: 2.2691 |  Val Loss: 2.3477 |  Train Acc: 0.151 |  Val Acc: 0.096
# Early Stopping Counter: 6/20
# Epoch 33/40 |  Train Loss: 2.2645 |  Val Loss: 2.3381 |  Train Acc: 0.157 |  Val Acc: 0.119
# Early Stopping Counter: 7/20
# Epoch 34/40 |  Train Loss: 2.2628 |  Val Loss: 2.3350 |  Train Acc: 0.156 |  Val Acc: 0.131
# Early Stopping Counter: 8/20
# Epoch 35/40 |  Train Loss: 2.2569 |  Val Loss: 2.3340 |  Train Acc: 0.156 |  Val Acc: 0.119
# Early Stopping Counter: 9/20
# Epoch 36/40 |  Train Loss: 2.2571 |  Val Loss: 2.3524 |  Train Acc: 0.152 |  Val Acc: 0.121
# Early Stopping Counter: 10/20
# Epoch 37/40 |  Train Loss: 2.2522 |  Val Loss: 2.3498 |  Train Acc: 0.160 |  Val Acc: 0.102
# Early Stopping Counter: 11/20
# Epoch 38/40 |  Train Loss: 2.2546 |  Val Loss: 2.3336 |  Train Acc: 0.156 |  Val Acc: 0.117
# Early Stopping Counter: 12/20
# Epoch 39/40 |  Train Loss: 2.2376 |  Val Loss: 2.3679 |  Train Acc: 0.172 |  Val Acc: 0.133
# Early Stopping Counter: 13/20
# Epoch 40/40 |  Train Loss: 2.2418 |  Val Loss: 2.3480 |  Train Acc: 0.167 |  Val Acc: 0.123
# Early Stopping Counter: 14/20
# Fold 7 Validation Accuracy: 0.1354
#
#
#
# Fold 8/15
# Epoch 1/40 |  Train Loss: 2.4887 |  Val Loss: 2.4401 |  Train Acc: 0.095 |  Val Acc: 0.100
# Epoch 2/40 |  Train Loss: 2.3947 |  Val Loss: 2.3859 |  Train Acc: 0.104 |  Val Acc: 0.081
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3898 |  Val Loss: 2.4436 |  Train Acc: 0.103 |  Val Acc: 0.113
# Epoch 4/40 |  Train Loss: 2.3688 |  Val Loss: 2.3614 |  Train Acc: 0.106 |  Val Acc: 0.098
# Early Stopping Counter: 1/20
# Epoch 5/40 |  Train Loss: 2.3484 |  Val Loss: 2.3240 |  Train Acc: 0.112 |  Val Acc: 0.110
# Early Stopping Counter: 2/20
# Epoch 6/40 |  Train Loss: 2.3508 |  Val Loss: 2.3458 |  Train Acc: 0.112 |  Val Acc: 0.110
# Early Stopping Counter: 3/20
# Epoch 7/40 |  Train Loss: 2.3457 |  Val Loss: 2.3360 |  Train Acc: 0.118 |  Val Acc: 0.113
# Early Stopping Counter: 4/20
# Epoch 8/40 |  Train Loss: 2.3396 |  Val Loss: 2.3661 |  Train Acc: 0.121 |  Val Acc: 0.092
# Early Stopping Counter: 5/20
# Epoch 9/40 |  Train Loss: 2.3376 |  Val Loss: 2.3611 |  Train Acc: 0.123 |  Val Acc: 0.096
# Early Stopping Counter: 6/20
# Epoch 10/40 |  Train Loss: 2.3359 |  Val Loss: 2.3791 |  Train Acc: 0.117 |  Val Acc: 0.113
# Early Stopping Counter: 7/20
# Epoch 11/40 |  Train Loss: 2.3361 |  Val Loss: 2.3446 |  Train Acc: 0.112 |  Val Acc: 0.108
# Early Stopping Counter: 8/20
# Epoch 12/40 |  Train Loss: 2.3244 |  Val Loss: 2.3762 |  Train Acc: 0.126 |  Val Acc: 0.106
# Early Stopping Counter: 9/20
# Epoch 13/40 |  Train Loss: 2.3164 |  Val Loss: 2.3131 |  Train Acc: 0.127 |  Val Acc: 0.121
# Epoch 14/40 |  Train Loss: 2.3187 |  Val Loss: 2.3240 |  Train Acc: 0.119 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 15/40 |  Train Loss: 2.3152 |  Val Loss: 2.3567 |  Train Acc: 0.125 |  Val Acc: 0.119
# Early Stopping Counter: 2/20
# Epoch 16/40 |  Train Loss: 2.3155 |  Val Loss: 2.3448 |  Train Acc: 0.124 |  Val Acc: 0.113
# Early Stopping Counter: 3/20
# Epoch 17/40 |  Train Loss: 2.3091 |  Val Loss: 2.3517 |  Train Acc: 0.130 |  Val Acc: 0.125
# Epoch 18/40 |  Train Loss: 2.3056 |  Val Loss: 2.3295 |  Train Acc: 0.130 |  Val Acc: 0.123
# Early Stopping Counter: 1/20
# Epoch 19/40 |  Train Loss: 2.2962 |  Val Loss: 2.3240 |  Train Acc: 0.140 |  Val Acc: 0.113
# Early Stopping Counter: 2/20
# Epoch 20/40 |  Train Loss: 2.2949 |  Val Loss: 2.3516 |  Train Acc: 0.137 |  Val Acc: 0.125
# Early Stopping Counter: 3/20
# Epoch 21/40 |  Train Loss: 2.2971 |  Val Loss: 2.3831 |  Train Acc: 0.137 |  Val Acc: 0.106
# Early Stopping Counter: 4/20
# Epoch 22/40 |  Train Loss: 2.2965 |  Val Loss: 2.3337 |  Train Acc: 0.144 |  Val Acc: 0.108
# Early Stopping Counter: 5/20
# Epoch 23/40 |  Train Loss: 2.2953 |  Val Loss: 2.3309 |  Train Acc: 0.138 |  Val Acc: 0.119
# Early Stopping Counter: 6/20
# Epoch 24/40 |  Train Loss: 2.2816 |  Val Loss: 2.3415 |  Train Acc: 0.146 |  Val Acc: 0.121
# Early Stopping Counter: 7/20
# Epoch 25/40 |  Train Loss: 2.2872 |  Val Loss: 2.3384 |  Train Acc: 0.142 |  Val Acc: 0.110
# Early Stopping Counter: 8/20
# Epoch 26/40 |  Train Loss: 2.2847 |  Val Loss: 2.3474 |  Train Acc: 0.139 |  Val Acc: 0.113
# Early Stopping Counter: 9/20
# Epoch 27/40 |  Train Loss: 2.2717 |  Val Loss: 2.3479 |  Train Acc: 0.151 |  Val Acc: 0.131
# Epoch 28/40 |  Train Loss: 2.2720 |  Val Loss: 2.3341 |  Train Acc: 0.155 |  Val Acc: 0.096
# Early Stopping Counter: 1/20
# Epoch 29/40 |  Train Loss: 2.2701 |  Val Loss: 2.3581 |  Train Acc: 0.157 |  Val Acc: 0.121
# Early Stopping Counter: 2/20
# Epoch 30/40 |  Train Loss: 2.2627 |  Val Loss: 2.3558 |  Train Acc: 0.154 |  Val Acc: 0.108
# Early Stopping Counter: 3/20
# Epoch 31/40 |  Train Loss: 2.2642 |  Val Loss: 2.3288 |  Train Acc: 0.149 |  Val Acc: 0.119
# Early Stopping Counter: 4/20
# Epoch 32/40 |  Train Loss: 2.2547 |  Val Loss: 2.3293 |  Train Acc: 0.163 |  Val Acc: 0.131
# Early Stopping Counter: 5/20
# Epoch 33/40 |  Train Loss: 2.2508 |  Val Loss: 2.3288 |  Train Acc: 0.165 |  Val Acc: 0.131
# Early Stopping Counter: 6/20
# Epoch 34/40 |  Train Loss: 2.2469 |  Val Loss: 2.3324 |  Train Acc: 0.170 |  Val Acc: 0.131
# Early Stopping Counter: 7/20
# Epoch 35/40 |  Train Loss: 2.2412 |  Val Loss: 2.3109 |  Train Acc: 0.168 |  Val Acc: 0.123
# Early Stopping Counter: 8/20
# Epoch 36/40 |  Train Loss: 2.2372 |  Val Loss: 2.3307 |  Train Acc: 0.175 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 37/40 |  Train Loss: 2.2345 |  Val Loss: 2.3401 |  Train Acc: 0.168 |  Val Acc: 0.135
# Epoch 38/40 |  Train Loss: 2.2255 |  Val Loss: 2.3510 |  Train Acc: 0.178 |  Val Acc: 0.123
# Early Stopping Counter: 1/20
# Epoch 39/40 |  Train Loss: 2.2143 |  Val Loss: 2.3487 |  Train Acc: 0.183 |  Val Acc: 0.119
# Early Stopping Counter: 2/20
# Epoch 40/40 |  Train Loss: 2.2035 |  Val Loss: 2.3700 |  Train Acc: 0.186 |  Val Acc: 0.121
# Early Stopping Counter: 3/20
# Fold 8 Validation Accuracy: 0.1354
#
#
#
# Fold 9/15
# Epoch 1/40 |  Train Loss: 2.4971 |  Val Loss: 2.3166 |  Train Acc: 0.096 |  Val Acc: 0.113
# Epoch 2/40 |  Train Loss: 2.4081 |  Val Loss: 2.3004 |  Train Acc: 0.102 |  Val Acc: 0.117
# Epoch 3/40 |  Train Loss: 2.3900 |  Val Loss: 2.2976 |  Train Acc: 0.105 |  Val Acc: 0.125
# Epoch 4/40 |  Train Loss: 2.3743 |  Val Loss: 2.2918 |  Train Acc: 0.107 |  Val Acc: 0.121
# Early Stopping Counter: 1/20
# Epoch 5/40 |  Train Loss: 2.3610 |  Val Loss: 2.2875 |  Train Acc: 0.106 |  Val Acc: 0.123
# Early Stopping Counter: 2/20
# Epoch 6/40 |  Train Loss: 2.3491 |  Val Loss: 2.2902 |  Train Acc: 0.110 |  Val Acc: 0.142
# Epoch 7/40 |  Train Loss: 2.3442 |  Val Loss: 2.2920 |  Train Acc: 0.110 |  Val Acc: 0.121
# Early Stopping Counter: 1/20
# Epoch 8/40 |  Train Loss: 2.3464 |  Val Loss: 2.2842 |  Train Acc: 0.115 |  Val Acc: 0.125
# Early Stopping Counter: 2/20
# Epoch 9/40 |  Train Loss: 2.3473 |  Val Loss: 2.2881 |  Train Acc: 0.113 |  Val Acc: 0.131
# Early Stopping Counter: 3/20
# Epoch 10/40 |  Train Loss: 2.3336 |  Val Loss: 2.2812 |  Train Acc: 0.121 |  Val Acc: 0.129
# Early Stopping Counter: 4/20
# Epoch 11/40 |  Train Loss: 2.3287 |  Val Loss: 2.2808 |  Train Acc: 0.124 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 12/40 |  Train Loss: 2.3245 |  Val Loss: 2.2829 |  Train Acc: 0.119 |  Val Acc: 0.163
# Epoch 13/40 |  Train Loss: 2.3254 |  Val Loss: 2.2778 |  Train Acc: 0.115 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 14/40 |  Train Loss: 2.3259 |  Val Loss: 2.2843 |  Train Acc: 0.115 |  Val Acc: 0.133
# Early Stopping Counter: 2/20
# Epoch 15/40 |  Train Loss: 2.3192 |  Val Loss: 2.2753 |  Train Acc: 0.116 |  Val Acc: 0.144
# Early Stopping Counter: 3/20
# Epoch 16/40 |  Train Loss: 2.3152 |  Val Loss: 2.2787 |  Train Acc: 0.129 |  Val Acc: 0.133
# Early Stopping Counter: 4/20
# Epoch 17/40 |  Train Loss: 2.3104 |  Val Loss: 2.2705 |  Train Acc: 0.127 |  Val Acc: 0.135
# Early Stopping Counter: 5/20
# Epoch 18/40 |  Train Loss: 2.3151 |  Val Loss: 2.2697 |  Train Acc: 0.117 |  Val Acc: 0.154
# Early Stopping Counter: 6/20
# Epoch 19/40 |  Train Loss: 2.3090 |  Val Loss: 2.2733 |  Train Acc: 0.119 |  Val Acc: 0.127
# Early Stopping Counter: 7/20
# Epoch 20/40 |  Train Loss: 2.3029 |  Val Loss: 2.2721 |  Train Acc: 0.126 |  Val Acc: 0.144
# Early Stopping Counter: 8/20
# Epoch 21/40 |  Train Loss: 2.3129 |  Val Loss: 2.2776 |  Train Acc: 0.121 |  Val Acc: 0.150
# Early Stopping Counter: 9/20
# Epoch 22/40 |  Train Loss: 2.3043 |  Val Loss: 2.2634 |  Train Acc: 0.127 |  Val Acc: 0.150
# Early Stopping Counter: 10/20
# Epoch 23/40 |  Train Loss: 2.3003 |  Val Loss: 2.2680 |  Train Acc: 0.130 |  Val Acc: 0.165
# Epoch 24/40 |  Train Loss: 2.2983 |  Val Loss: 2.2677 |  Train Acc: 0.131 |  Val Acc: 0.154
# Early Stopping Counter: 1/20
# Epoch 25/40 |  Train Loss: 2.2943 |  Val Loss: 2.2739 |  Train Acc: 0.134 |  Val Acc: 0.154
# Early Stopping Counter: 2/20
# Epoch 26/40 |  Train Loss: 2.2936 |  Val Loss: 2.2702 |  Train Acc: 0.131 |  Val Acc: 0.165
# Early Stopping Counter: 3/20
# Epoch 27/40 |  Train Loss: 2.2874 |  Val Loss: 2.2656 |  Train Acc: 0.135 |  Val Acc: 0.152
# Early Stopping Counter: 4/20
# Epoch 28/40 |  Train Loss: 2.2923 |  Val Loss: 2.2703 |  Train Acc: 0.139 |  Val Acc: 0.171
# Epoch 29/40 |  Train Loss: 2.2865 |  Val Loss: 2.2737 |  Train Acc: 0.132 |  Val Acc: 0.156
# Early Stopping Counter: 1/20
# Epoch 30/40 |  Train Loss: 2.2789 |  Val Loss: 2.2665 |  Train Acc: 0.140 |  Val Acc: 0.177
# Epoch 31/40 |  Train Loss: 2.2792 |  Val Loss: 2.2665 |  Train Acc: 0.136 |  Val Acc: 0.175
# Early Stopping Counter: 1/20
# Epoch 32/40 |  Train Loss: 2.2777 |  Val Loss: 2.2731 |  Train Acc: 0.143 |  Val Acc: 0.169
# Early Stopping Counter: 2/20
# Epoch 33/40 |  Train Loss: 2.2757 |  Val Loss: 2.2615 |  Train Acc: 0.149 |  Val Acc: 0.183
# Epoch 34/40 |  Train Loss: 2.2714 |  Val Loss: 2.2702 |  Train Acc: 0.148 |  Val Acc: 0.144
# Early Stopping Counter: 1/20
# Epoch 35/40 |  Train Loss: 2.2655 |  Val Loss: 2.2726 |  Train Acc: 0.148 |  Val Acc: 0.142
# Early Stopping Counter: 2/20
# Epoch 36/40 |  Train Loss: 2.2642 |  Val Loss: 2.2798 |  Train Acc: 0.151 |  Val Acc: 0.146
# Early Stopping Counter: 3/20
# Epoch 37/40 |  Train Loss: 2.2563 |  Val Loss: 2.2754 |  Train Acc: 0.164 |  Val Acc: 0.146
# Early Stopping Counter: 4/20
# Epoch 38/40 |  Train Loss: 2.2592 |  Val Loss: 2.2777 |  Train Acc: 0.156 |  Val Acc: 0.140
# Early Stopping Counter: 5/20
# Epoch 39/40 |  Train Loss: 2.2545 |  Val Loss: 2.2867 |  Train Acc: 0.157 |  Val Acc: 0.150
# Early Stopping Counter: 6/20
# Epoch 40/40 |  Train Loss: 2.2472 |  Val Loss: 2.2904 |  Train Acc: 0.161 |  Val Acc: 0.135
# Early Stopping Counter: 7/20
# Fold 9 Validation Accuracy: 0.1833
#
#
#
# Fold 10/15
# Epoch 1/40 |  Train Loss: 2.4959 |  Val Loss: 2.2991 |  Train Acc: 0.099 |  Val Acc: 0.115
# Epoch 2/40 |  Train Loss: 2.4164 |  Val Loss: 2.2984 |  Train Acc: 0.101 |  Val Acc: 0.110
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.4001 |  Val Loss: 2.3009 |  Train Acc: 0.106 |  Val Acc: 0.108
# Early Stopping Counter: 2/20
# Epoch 4/40 |  Train Loss: 2.3749 |  Val Loss: 2.3030 |  Train Acc: 0.105 |  Val Acc: 0.117
# Epoch 5/40 |  Train Loss: 2.3487 |  Val Loss: 2.3023 |  Train Acc: 0.119 |  Val Acc: 0.094
# Early Stopping Counter: 1/20
# Epoch 6/40 |  Train Loss: 2.3546 |  Val Loss: 2.2971 |  Train Acc: 0.120 |  Val Acc: 0.100
# Early Stopping Counter: 2/20
# Epoch 7/40 |  Train Loss: 2.3465 |  Val Loss: 2.2998 |  Train Acc: 0.114 |  Val Acc: 0.115
# Early Stopping Counter: 3/20
# Epoch 8/40 |  Train Loss: 2.3430 |  Val Loss: 2.2968 |  Train Acc: 0.117 |  Val Acc: 0.115
# Early Stopping Counter: 4/20
# Epoch 9/40 |  Train Loss: 2.3399 |  Val Loss: 2.3048 |  Train Acc: 0.112 |  Val Acc: 0.096
# Early Stopping Counter: 5/20
# Epoch 10/40 |  Train Loss: 2.3335 |  Val Loss: 2.3048 |  Train Acc: 0.119 |  Val Acc: 0.110
# Early Stopping Counter: 6/20
# Epoch 11/40 |  Train Loss: 2.3324 |  Val Loss: 2.2954 |  Train Acc: 0.112 |  Val Acc: 0.108
# Early Stopping Counter: 7/20
# Epoch 12/40 |  Train Loss: 2.3204 |  Val Loss: 2.3001 |  Train Acc: 0.118 |  Val Acc: 0.113
# Early Stopping Counter: 8/20
# Epoch 13/40 |  Train Loss: 2.3226 |  Val Loss: 2.3019 |  Train Acc: 0.119 |  Val Acc: 0.117
# Early Stopping Counter: 9/20
# Epoch 14/40 |  Train Loss: 2.3108 |  Val Loss: 2.2994 |  Train Acc: 0.134 |  Val Acc: 0.117
# Early Stopping Counter: 10/20
# Epoch 15/40 |  Train Loss: 2.3136 |  Val Loss: 2.2965 |  Train Acc: 0.121 |  Val Acc: 0.115
# Early Stopping Counter: 11/20
# Epoch 16/40 |  Train Loss: 2.3116 |  Val Loss: 2.2937 |  Train Acc: 0.120 |  Val Acc: 0.117
# Early Stopping Counter: 12/20
# Epoch 17/40 |  Train Loss: 2.3078 |  Val Loss: 2.2948 |  Train Acc: 0.128 |  Val Acc: 0.121
# Epoch 18/40 |  Train Loss: 2.3023 |  Val Loss: 2.2985 |  Train Acc: 0.123 |  Val Acc: 0.115
# Early Stopping Counter: 1/20
# Epoch 19/40 |  Train Loss: 2.2994 |  Val Loss: 2.2947 |  Train Acc: 0.130 |  Val Acc: 0.113
# Early Stopping Counter: 2/20
# Epoch 20/40 |  Train Loss: 2.2982 |  Val Loss: 2.3002 |  Train Acc: 0.133 |  Val Acc: 0.098
# Early Stopping Counter: 3/20
# Epoch 21/40 |  Train Loss: 2.2907 |  Val Loss: 2.2969 |  Train Acc: 0.144 |  Val Acc: 0.123
# Epoch 22/40 |  Train Loss: 2.2950 |  Val Loss: 2.2992 |  Train Acc: 0.146 |  Val Acc: 0.108
# Early Stopping Counter: 1/20
# Epoch 23/40 |  Train Loss: 2.2875 |  Val Loss: 2.2976 |  Train Acc: 0.142 |  Val Acc: 0.096
# Early Stopping Counter: 2/20
# Epoch 24/40 |  Train Loss: 2.2799 |  Val Loss: 2.2976 |  Train Acc: 0.145 |  Val Acc: 0.123
# Early Stopping Counter: 3/20
# Epoch 25/40 |  Train Loss: 2.2860 |  Val Loss: 2.2985 |  Train Acc: 0.145 |  Val Acc: 0.108
# Early Stopping Counter: 4/20
# Epoch 26/40 |  Train Loss: 2.2848 |  Val Loss: 2.3008 |  Train Acc: 0.141 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 27/40 |  Train Loss: 2.2763 |  Val Loss: 2.3117 |  Train Acc: 0.153 |  Val Acc: 0.121
# Early Stopping Counter: 6/20
# Epoch 28/40 |  Train Loss: 2.2711 |  Val Loss: 2.3085 |  Train Acc: 0.149 |  Val Acc: 0.110
# Early Stopping Counter: 7/20
# Epoch 29/40 |  Train Loss: 2.2670 |  Val Loss: 2.3031 |  Train Acc: 0.156 |  Val Acc: 0.106
# Early Stopping Counter: 8/20
# Epoch 30/40 |  Train Loss: 2.2626 |  Val Loss: 2.2966 |  Train Acc: 0.156 |  Val Acc: 0.135
# Epoch 31/40 |  Train Loss: 2.2609 |  Val Loss: 2.3076 |  Train Acc: 0.155 |  Val Acc: 0.104
# Early Stopping Counter: 1/20
# Epoch 32/40 |  Train Loss: 2.2595 |  Val Loss: 2.3026 |  Train Acc: 0.159 |  Val Acc: 0.087
# Early Stopping Counter: 2/20
# Epoch 33/40 |  Train Loss: 2.2548 |  Val Loss: 2.3079 |  Train Acc: 0.158 |  Val Acc: 0.106
# Early Stopping Counter: 3/20
# Epoch 34/40 |  Train Loss: 2.2477 |  Val Loss: 2.3086 |  Train Acc: 0.169 |  Val Acc: 0.115
# Early Stopping Counter: 4/20
# Epoch 35/40 |  Train Loss: 2.2432 |  Val Loss: 2.3150 |  Train Acc: 0.175 |  Val Acc: 0.096
# Early Stopping Counter: 5/20
# Epoch 36/40 |  Train Loss: 2.2394 |  Val Loss: 2.3188 |  Train Acc: 0.169 |  Val Acc: 0.094
# Early Stopping Counter: 6/20
# Epoch 37/40 |  Train Loss: 2.2327 |  Val Loss: 2.3131 |  Train Acc: 0.172 |  Val Acc: 0.110
# Early Stopping Counter: 7/20
# Epoch 38/40 |  Train Loss: 2.2221 |  Val Loss: 2.3217 |  Train Acc: 0.182 |  Val Acc: 0.100
# Early Stopping Counter: 8/20
# Epoch 39/40 |  Train Loss: 2.2190 |  Val Loss: 2.3328 |  Train Acc: 0.187 |  Val Acc: 0.102
# Early Stopping Counter: 9/20
# Epoch 40/40 |  Train Loss: 2.2167 |  Val Loss: 2.3370 |  Train Acc: 0.181 |  Val Acc: 0.115
# Early Stopping Counter: 10/20
# Fold 10 Validation Accuracy: 0.1354
#
#
#
# Fold 11/15
# Epoch 1/40 |  Train Loss: 2.4958 |  Val Loss: 2.3121 |  Train Acc: 0.098 |  Val Acc: 0.092
# Epoch 2/40 |  Train Loss: 2.3971 |  Val Loss: 2.3086 |  Train Acc: 0.100 |  Val Acc: 0.106
# Epoch 3/40 |  Train Loss: 2.3877 |  Val Loss: 2.3104 |  Train Acc: 0.102 |  Val Acc: 0.092
# Early Stopping Counter: 1/20
# Epoch 4/40 |  Train Loss: 2.3804 |  Val Loss: 2.3048 |  Train Acc: 0.099 |  Val Acc: 0.104
# Early Stopping Counter: 2/20
# Epoch 5/40 |  Train Loss: 2.3651 |  Val Loss: 2.3041 |  Train Acc: 0.108 |  Val Acc: 0.087
# Early Stopping Counter: 3/20
# Epoch 6/40 |  Train Loss: 2.3417 |  Val Loss: 2.3037 |  Train Acc: 0.116 |  Val Acc: 0.127
# Epoch 7/40 |  Train Loss: 2.3468 |  Val Loss: 2.3072 |  Train Acc: 0.110 |  Val Acc: 0.106
# Early Stopping Counter: 1/20
# Epoch 8/40 |  Train Loss: 2.3451 |  Val Loss: 2.3057 |  Train Acc: 0.108 |  Val Acc: 0.090
# Early Stopping Counter: 2/20
# Epoch 9/40 |  Train Loss: 2.3358 |  Val Loss: 2.3104 |  Train Acc: 0.114 |  Val Acc: 0.110
# Early Stopping Counter: 3/20
# Epoch 10/40 |  Train Loss: 2.3266 |  Val Loss: 2.3061 |  Train Acc: 0.114 |  Val Acc: 0.117
# Early Stopping Counter: 4/20
# Epoch 11/40 |  Train Loss: 2.3212 |  Val Loss: 2.3094 |  Train Acc: 0.121 |  Val Acc: 0.104
# Early Stopping Counter: 5/20
# Epoch 12/40 |  Train Loss: 2.3228 |  Val Loss: 2.3061 |  Train Acc: 0.118 |  Val Acc: 0.115
# Early Stopping Counter: 6/20
# Epoch 13/40 |  Train Loss: 2.3169 |  Val Loss: 2.3092 |  Train Acc: 0.118 |  Val Acc: 0.100
# Early Stopping Counter: 7/20
# Epoch 14/40 |  Train Loss: 2.3126 |  Val Loss: 2.3086 |  Train Acc: 0.125 |  Val Acc: 0.092
# Early Stopping Counter: 8/20
# Epoch 15/40 |  Train Loss: 2.3153 |  Val Loss: 2.3131 |  Train Acc: 0.125 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 16/40 |  Train Loss: 2.3153 |  Val Loss: 2.3133 |  Train Acc: 0.126 |  Val Acc: 0.108
# Early Stopping Counter: 10/20
# Epoch 17/40 |  Train Loss: 2.3032 |  Val Loss: 2.3107 |  Train Acc: 0.130 |  Val Acc: 0.102
# Early Stopping Counter: 11/20
# Epoch 18/40 |  Train Loss: 2.3025 |  Val Loss: 2.3098 |  Train Acc: 0.139 |  Val Acc: 0.108
# Early Stopping Counter: 12/20
# Epoch 19/40 |  Train Loss: 2.3102 |  Val Loss: 2.3143 |  Train Acc: 0.126 |  Val Acc: 0.100
# Early Stopping Counter: 13/20
# Epoch 20/40 |  Train Loss: 2.2975 |  Val Loss: 2.3178 |  Train Acc: 0.139 |  Val Acc: 0.115
# Early Stopping Counter: 14/20
# Epoch 21/40 |  Train Loss: 2.2894 |  Val Loss: 2.3241 |  Train Acc: 0.136 |  Val Acc: 0.121
# Early Stopping Counter: 15/20
# Epoch 22/40 |  Train Loss: 2.2912 |  Val Loss: 2.3132 |  Train Acc: 0.131 |  Val Acc: 0.102
# Early Stopping Counter: 16/20
# Epoch 23/40 |  Train Loss: 2.2891 |  Val Loss: 2.3147 |  Train Acc: 0.136 |  Val Acc: 0.113
# Early Stopping Counter: 17/20
# Epoch 24/40 |  Train Loss: 2.2880 |  Val Loss: 2.3067 |  Train Acc: 0.138 |  Val Acc: 0.096
# Early Stopping Counter: 18/20
# Epoch 25/40 |  Train Loss: 2.2841 |  Val Loss: 2.3083 |  Train Acc: 0.139 |  Val Acc: 0.121
# Early Stopping Counter: 19/20
# Epoch 26/40 |  Train Loss: 2.2840 |  Val Loss: 2.3237 |  Train Acc: 0.146 |  Val Acc: 0.113
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 26
# Fold 11 Validation Accuracy: 0.1271
#
#
#
# Fold 12/15
# Epoch 1/40 |  Train Loss: 2.4768 |  Val Loss: 2.3538 |  Train Acc: 0.102 |  Val Acc: 0.087
# Epoch 2/40 |  Train Loss: 2.4008 |  Val Loss: 2.3326 |  Train Acc: 0.108 |  Val Acc: 0.110
# Epoch 3/40 |  Train Loss: 2.3774 |  Val Loss: 2.3526 |  Train Acc: 0.109 |  Val Acc: 0.108
# Early Stopping Counter: 1/20
# Epoch 4/40 |  Train Loss: 2.3736 |  Val Loss: 2.3336 |  Train Acc: 0.108 |  Val Acc: 0.110
# Early Stopping Counter: 2/20
# Epoch 5/40 |  Train Loss: 2.3652 |  Val Loss: 2.3345 |  Train Acc: 0.109 |  Val Acc: 0.106
# Early Stopping Counter: 3/20
# Epoch 6/40 |  Train Loss: 2.3527 |  Val Loss: 2.3166 |  Train Acc: 0.110 |  Val Acc: 0.146
# Epoch 7/40 |  Train Loss: 2.3425 |  Val Loss: 2.3234 |  Train Acc: 0.113 |  Val Acc: 0.133
# Early Stopping Counter: 1/20
# Epoch 8/40 |  Train Loss: 2.3451 |  Val Loss: 2.3337 |  Train Acc: 0.111 |  Val Acc: 0.123
# Early Stopping Counter: 2/20
# Epoch 9/40 |  Train Loss: 2.3309 |  Val Loss: 2.3276 |  Train Acc: 0.117 |  Val Acc: 0.117
# Early Stopping Counter: 3/20
# Epoch 10/40 |  Train Loss: 2.3235 |  Val Loss: 2.3188 |  Train Acc: 0.122 |  Val Acc: 0.110
# Early Stopping Counter: 4/20
# Epoch 11/40 |  Train Loss: 2.3223 |  Val Loss: 2.3357 |  Train Acc: 0.115 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 12/40 |  Train Loss: 2.3223 |  Val Loss: 2.3366 |  Train Acc: 0.121 |  Val Acc: 0.121
# Early Stopping Counter: 6/20
# Epoch 13/40 |  Train Loss: 2.3126 |  Val Loss: 2.3523 |  Train Acc: 0.130 |  Val Acc: 0.113
# Early Stopping Counter: 7/20
# Epoch 14/40 |  Train Loss: 2.3135 |  Val Loss: 2.3470 |  Train Acc: 0.127 |  Val Acc: 0.094
# Early Stopping Counter: 8/20
# Epoch 15/40 |  Train Loss: 2.3071 |  Val Loss: 2.3386 |  Train Acc: 0.128 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 16/40 |  Train Loss: 2.3078 |  Val Loss: 2.3309 |  Train Acc: 0.132 |  Val Acc: 0.106
# Early Stopping Counter: 10/20
# Epoch 17/40 |  Train Loss: 2.3018 |  Val Loss: 2.3356 |  Train Acc: 0.130 |  Val Acc: 0.117
# Early Stopping Counter: 11/20
# Epoch 18/40 |  Train Loss: 2.3014 |  Val Loss: 2.3262 |  Train Acc: 0.140 |  Val Acc: 0.117
# Early Stopping Counter: 12/20
# Epoch 19/40 |  Train Loss: 2.3031 |  Val Loss: 2.3239 |  Train Acc: 0.129 |  Val Acc: 0.119
# Early Stopping Counter: 13/20
# Epoch 20/40 |  Train Loss: 2.2961 |  Val Loss: 2.3614 |  Train Acc: 0.134 |  Val Acc: 0.102
# Early Stopping Counter: 14/20
# Epoch 21/40 |  Train Loss: 2.2878 |  Val Loss: 2.3426 |  Train Acc: 0.138 |  Val Acc: 0.102
# Early Stopping Counter: 15/20
# Epoch 22/40 |  Train Loss: 2.2972 |  Val Loss: 2.3357 |  Train Acc: 0.138 |  Val Acc: 0.102
# Early Stopping Counter: 16/20
# Epoch 23/40 |  Train Loss: 2.2861 |  Val Loss: 2.3372 |  Train Acc: 0.140 |  Val Acc: 0.108
# Early Stopping Counter: 17/20
# Epoch 24/40 |  Train Loss: 2.2817 |  Val Loss: 2.3405 |  Train Acc: 0.136 |  Val Acc: 0.113
# Early Stopping Counter: 18/20
# Epoch 25/40 |  Train Loss: 2.2816 |  Val Loss: 2.3306 |  Train Acc: 0.144 |  Val Acc: 0.119
# Early Stopping Counter: 19/20
# Epoch 26/40 |  Train Loss: 2.2779 |  Val Loss: 2.3374 |  Train Acc: 0.147 |  Val Acc: 0.115
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 26
# Fold 12 Validation Accuracy: 0.1458
#
#
#
# Fold 13/15
# Epoch 1/40 |  Train Loss: 2.4761 |  Val Loss: 2.3073 |  Train Acc: 0.104 |  Val Acc: 0.098
# Epoch 2/40 |  Train Loss: 2.4029 |  Val Loss: 2.3047 |  Train Acc: 0.106 |  Val Acc: 0.092
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3797 |  Val Loss: 2.3042 |  Train Acc: 0.114 |  Val Acc: 0.106
# Epoch 4/40 |  Train Loss: 2.3774 |  Val Loss: 2.3044 |  Train Acc: 0.108 |  Val Acc: 0.073
# Early Stopping Counter: 1/20
# Epoch 5/40 |  Train Loss: 2.3561 |  Val Loss: 2.3014 |  Train Acc: 0.111 |  Val Acc: 0.113
# Epoch 6/40 |  Train Loss: 2.3488 |  Val Loss: 2.3027 |  Train Acc: 0.115 |  Val Acc: 0.102
# Early Stopping Counter: 1/20
# Epoch 7/40 |  Train Loss: 2.3469 |  Val Loss: 2.3033 |  Train Acc: 0.114 |  Val Acc: 0.092
# Early Stopping Counter: 2/20
# Epoch 8/40 |  Train Loss: 2.3423 |  Val Loss: 2.3039 |  Train Acc: 0.114 |  Val Acc: 0.079
# Early Stopping Counter: 3/20
# Epoch 9/40 |  Train Loss: 2.3432 |  Val Loss: 2.3039 |  Train Acc: 0.113 |  Val Acc: 0.087
# Early Stopping Counter: 4/20
# Epoch 10/40 |  Train Loss: 2.3341 |  Val Loss: 2.3033 |  Train Acc: 0.125 |  Val Acc: 0.094
# Early Stopping Counter: 5/20
# Epoch 11/40 |  Train Loss: 2.3291 |  Val Loss: 2.3026 |  Train Acc: 0.127 |  Val Acc: 0.094
# Early Stopping Counter: 6/20
# Epoch 12/40 |  Train Loss: 2.3227 |  Val Loss: 2.3047 |  Train Acc: 0.120 |  Val Acc: 0.094
# Early Stopping Counter: 7/20
# Epoch 13/40 |  Train Loss: 2.3237 |  Val Loss: 2.3043 |  Train Acc: 0.122 |  Val Acc: 0.090
# Early Stopping Counter: 8/20
# Epoch 14/40 |  Train Loss: 2.3220 |  Val Loss: 2.3023 |  Train Acc: 0.121 |  Val Acc: 0.106
# Early Stopping Counter: 9/20
# Epoch 15/40 |  Train Loss: 2.3153 |  Val Loss: 2.3048 |  Train Acc: 0.128 |  Val Acc: 0.096
# Early Stopping Counter: 10/20
# Epoch 16/40 |  Train Loss: 2.3159 |  Val Loss: 2.3029 |  Train Acc: 0.123 |  Val Acc: 0.098
# Early Stopping Counter: 11/20
# Epoch 17/40 |  Train Loss: 2.3148 |  Val Loss: 2.3017 |  Train Acc: 0.125 |  Val Acc: 0.115
# Epoch 18/40 |  Train Loss: 2.3068 |  Val Loss: 2.3018 |  Train Acc: 0.124 |  Val Acc: 0.087
# Early Stopping Counter: 1/20
# Epoch 19/40 |  Train Loss: 2.3031 |  Val Loss: 2.3029 |  Train Acc: 0.130 |  Val Acc: 0.123
# Epoch 20/40 |  Train Loss: 2.3019 |  Val Loss: 2.3004 |  Train Acc: 0.137 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 21/40 |  Train Loss: 2.3029 |  Val Loss: 2.3015 |  Train Acc: 0.137 |  Val Acc: 0.100
# Early Stopping Counter: 2/20
# Epoch 22/40 |  Train Loss: 2.2938 |  Val Loss: 2.3027 |  Train Acc: 0.140 |  Val Acc: 0.104
# Early Stopping Counter: 3/20
# Epoch 23/40 |  Train Loss: 2.2962 |  Val Loss: 2.3016 |  Train Acc: 0.134 |  Val Acc: 0.106
# Early Stopping Counter: 4/20
# Epoch 24/40 |  Train Loss: 2.2953 |  Val Loss: 2.3003 |  Train Acc: 0.142 |  Val Acc: 0.119
# Early Stopping Counter: 5/20
# Epoch 25/40 |  Train Loss: 2.2891 |  Val Loss: 2.3014 |  Train Acc: 0.141 |  Val Acc: 0.090
# Early Stopping Counter: 6/20
# Epoch 26/40 |  Train Loss: 2.2851 |  Val Loss: 2.3008 |  Train Acc: 0.137 |  Val Acc: 0.110
# Early Stopping Counter: 7/20
# Epoch 27/40 |  Train Loss: 2.2779 |  Val Loss: 2.3075 |  Train Acc: 0.141 |  Val Acc: 0.102
# Early Stopping Counter: 8/20
# Epoch 28/40 |  Train Loss: 2.2828 |  Val Loss: 2.3028 |  Train Acc: 0.147 |  Val Acc: 0.104
# Early Stopping Counter: 9/20
# Epoch 29/40 |  Train Loss: 2.2733 |  Val Loss: 2.3041 |  Train Acc: 0.145 |  Val Acc: 0.108
# Early Stopping Counter: 10/20
# Epoch 30/40 |  Train Loss: 2.2778 |  Val Loss: 2.3010 |  Train Acc: 0.142 |  Val Acc: 0.106
# Early Stopping Counter: 11/20
# Epoch 31/40 |  Train Loss: 2.2653 |  Val Loss: 2.3031 |  Train Acc: 0.152 |  Val Acc: 0.110
# Early Stopping Counter: 12/20
# Epoch 32/40 |  Train Loss: 2.2676 |  Val Loss: 2.2958 |  Train Acc: 0.151 |  Val Acc: 0.117
# Early Stopping Counter: 13/20
# Epoch 33/40 |  Train Loss: 2.2639 |  Val Loss: 2.3026 |  Train Acc: 0.151 |  Val Acc: 0.090
# Early Stopping Counter: 14/20
# Epoch 34/40 |  Train Loss: 2.2629 |  Val Loss: 2.2978 |  Train Acc: 0.157 |  Val Acc: 0.106
# Early Stopping Counter: 15/20
# Epoch 35/40 |  Train Loss: 2.2521 |  Val Loss: 2.3023 |  Train Acc: 0.158 |  Val Acc: 0.108
# Early Stopping Counter: 16/20
# Epoch 36/40 |  Train Loss: 2.2487 |  Val Loss: 2.3126 |  Train Acc: 0.166 |  Val Acc: 0.104
# Early Stopping Counter: 17/20
# Epoch 37/40 |  Train Loss: 2.2445 |  Val Loss: 2.2956 |  Train Acc: 0.169 |  Val Acc: 0.108
# Early Stopping Counter: 18/20
# Epoch 38/40 |  Train Loss: 2.2369 |  Val Loss: 2.3113 |  Train Acc: 0.173 |  Val Acc: 0.106
# Early Stopping Counter: 19/20
# Epoch 39/40 |  Train Loss: 2.2375 |  Val Loss: 2.3184 |  Train Acc: 0.170 |  Val Acc: 0.100
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 39
# Fold 13 Validation Accuracy: 0.1229
#
#
#
# Fold 14/15
# Epoch 1/40 |  Train Loss: 2.4822 |  Val Loss: 2.3179 |  Train Acc: 0.106 |  Val Acc: 0.102
# Epoch 2/40 |  Train Loss: 2.4223 |  Val Loss: 2.3108 |  Train Acc: 0.106 |  Val Acc: 0.083
# Early Stopping Counter: 1/20
# Epoch 3/40 |  Train Loss: 2.3981 |  Val Loss: 2.3056 |  Train Acc: 0.105 |  Val Acc: 0.087
# Early Stopping Counter: 2/20
# Epoch 4/40 |  Train Loss: 2.3813 |  Val Loss: 2.3090 |  Train Acc: 0.112 |  Val Acc: 0.113
# Epoch 5/40 |  Train Loss: 2.3827 |  Val Loss: 2.3041 |  Train Acc: 0.111 |  Val Acc: 0.115
# Epoch 6/40 |  Train Loss: 2.3631 |  Val Loss: 2.3060 |  Train Acc: 0.108 |  Val Acc: 0.115
# Early Stopping Counter: 1/20
# Epoch 7/40 |  Train Loss: 2.3560 |  Val Loss: 2.3003 |  Train Acc: 0.114 |  Val Acc: 0.110
# Early Stopping Counter: 2/20
# Epoch 8/40 |  Train Loss: 2.3550 |  Val Loss: 2.3050 |  Train Acc: 0.111 |  Val Acc: 0.106
# Early Stopping Counter: 3/20
# Epoch 9/40 |  Train Loss: 2.3420 |  Val Loss: 2.3048 |  Train Acc: 0.120 |  Val Acc: 0.110
# Early Stopping Counter: 4/20
# Epoch 10/40 |  Train Loss: 2.3567 |  Val Loss: 2.3025 |  Train Acc: 0.113 |  Val Acc: 0.117
# Epoch 11/40 |  Train Loss: 2.3432 |  Val Loss: 2.3059 |  Train Acc: 0.119 |  Val Acc: 0.108
# Early Stopping Counter: 1/20
# Epoch 12/40 |  Train Loss: 2.3376 |  Val Loss: 2.3019 |  Train Acc: 0.128 |  Val Acc: 0.121
# Epoch 13/40 |  Train Loss: 2.3383 |  Val Loss: 2.3033 |  Train Acc: 0.123 |  Val Acc: 0.119
# Early Stopping Counter: 1/20
# Epoch 14/40 |  Train Loss: 2.3239 |  Val Loss: 2.3013 |  Train Acc: 0.119 |  Val Acc: 0.121
# Early Stopping Counter: 2/20
# Epoch 15/40 |  Train Loss: 2.3318 |  Val Loss: 2.2975 |  Train Acc: 0.124 |  Val Acc: 0.121
# Early Stopping Counter: 3/20
# Epoch 16/40 |  Train Loss: 2.3220 |  Val Loss: 2.3001 |  Train Acc: 0.126 |  Val Acc: 0.121
# Early Stopping Counter: 4/20
# Epoch 17/40 |  Train Loss: 2.3209 |  Val Loss: 2.3081 |  Train Acc: 0.127 |  Val Acc: 0.121
# Early Stopping Counter: 5/20
# Epoch 18/40 |  Train Loss: 2.3223 |  Val Loss: 2.2995 |  Train Acc: 0.127 |  Val Acc: 0.115
# Early Stopping Counter: 6/20
# Epoch 19/40 |  Train Loss: 2.3121 |  Val Loss: 2.3061 |  Train Acc: 0.131 |  Val Acc: 0.123
# Epoch 20/40 |  Train Loss: 2.3116 |  Val Loss: 2.3057 |  Train Acc: 0.132 |  Val Acc: 0.108
# Early Stopping Counter: 1/20
# Epoch 21/40 |  Train Loss: 2.3034 |  Val Loss: 2.3097 |  Train Acc: 0.138 |  Val Acc: 0.115
# Early Stopping Counter: 2/20
# Epoch 22/40 |  Train Loss: 2.3038 |  Val Loss: 2.3144 |  Train Acc: 0.133 |  Val Acc: 0.115
# Early Stopping Counter: 3/20
# Epoch 23/40 |  Train Loss: 2.2940 |  Val Loss: 2.3064 |  Train Acc: 0.138 |  Val Acc: 0.115
# Early Stopping Counter: 4/20
# Epoch 24/40 |  Train Loss: 2.2904 |  Val Loss: 2.3030 |  Train Acc: 0.144 |  Val Acc: 0.106
# Early Stopping Counter: 5/20
# Epoch 25/40 |  Train Loss: 2.2917 |  Val Loss: 2.3037 |  Train Acc: 0.142 |  Val Acc: 0.129
# Epoch 26/40 |  Train Loss: 2.2923 |  Val Loss: 2.3059 |  Train Acc: 0.140 |  Val Acc: 0.133
# Epoch 27/40 |  Train Loss: 2.2885 |  Val Loss: 2.3081 |  Train Acc: 0.138 |  Val Acc: 0.123
# Early Stopping Counter: 1/20
# Epoch 28/40 |  Train Loss: 2.2863 |  Val Loss: 2.2997 |  Train Acc: 0.149 |  Val Acc: 0.127
# Early Stopping Counter: 2/20
# Epoch 29/40 |  Train Loss: 2.2778 |  Val Loss: 2.3137 |  Train Acc: 0.147 |  Val Acc: 0.110
# Early Stopping Counter: 3/20
# Epoch 30/40 |  Train Loss: 2.2785 |  Val Loss: 2.3067 |  Train Acc: 0.149 |  Val Acc: 0.133
# Early Stopping Counter: 4/20
# Epoch 31/40 |  Train Loss: 2.2702 |  Val Loss: 2.3171 |  Train Acc: 0.158 |  Val Acc: 0.117
# Early Stopping Counter: 5/20
# Epoch 32/40 |  Train Loss: 2.2670 |  Val Loss: 2.3089 |  Train Acc: 0.160 |  Val Acc: 0.108
# Early Stopping Counter: 6/20
# Epoch 33/40 |  Train Loss: 2.2677 |  Val Loss: 2.3194 |  Train Acc: 0.155 |  Val Acc: 0.119
# Early Stopping Counter: 7/20
# Epoch 34/40 |  Train Loss: 2.2669 |  Val Loss: 2.3207 |  Train Acc: 0.153 |  Val Acc: 0.110
# Early Stopping Counter: 8/20
# Epoch 35/40 |  Train Loss: 2.2645 |  Val Loss: 2.3266 |  Train Acc: 0.163 |  Val Acc: 0.110
# Early Stopping Counter: 9/20
# Epoch 36/40 |  Train Loss: 2.2561 |  Val Loss: 2.3296 |  Train Acc: 0.164 |  Val Acc: 0.121
# Early Stopping Counter: 10/20
# Epoch 37/40 |  Train Loss: 2.2451 |  Val Loss: 2.3218 |  Train Acc: 0.165 |  Val Acc: 0.102
# Early Stopping Counter: 11/20
# Epoch 38/40 |  Train Loss: 2.2461 |  Val Loss: 2.3264 |  Train Acc: 0.169 |  Val Acc: 0.106
# Early Stopping Counter: 12/20
# Epoch 39/40 |  Train Loss: 2.2355 |  Val Loss: 2.3295 |  Train Acc: 0.171 |  Val Acc: 0.108
# Early Stopping Counter: 13/20
# Epoch 40/40 |  Train Loss: 2.2284 |  Val Loss: 2.3326 |  Train Acc: 0.176 |  Val Acc: 0.108
# Early Stopping Counter: 14/20
# Fold 14 Validation Accuracy: 0.1333
#
#
#
# Fold 15/15
# Epoch 1/40 |  Train Loss: 2.4867 |  Val Loss: 2.3395 |  Train Acc: 0.101 |  Val Acc: 0.092
# Epoch 2/40 |  Train Loss: 2.4061 |  Val Loss: 2.3189 |  Train Acc: 0.097 |  Val Acc: 0.100
# Epoch 3/40 |  Train Loss: 2.3803 |  Val Loss: 2.3151 |  Train Acc: 0.111 |  Val Acc: 0.104
# Epoch 4/40 |  Train Loss: 2.3668 |  Val Loss: 2.3065 |  Train Acc: 0.112 |  Val Acc: 0.115
# Epoch 5/40 |  Train Loss: 2.3596 |  Val Loss: 2.3209 |  Train Acc: 0.104 |  Val Acc: 0.102
# Early Stopping Counter: 1/20
# Epoch 6/40 |  Train Loss: 2.3540 |  Val Loss: 2.3268 |  Train Acc: 0.107 |  Val Acc: 0.133
# Epoch 7/40 |  Train Loss: 2.3534 |  Val Loss: 2.3106 |  Train Acc: 0.112 |  Val Acc: 0.121
# Early Stopping Counter: 1/20
# Epoch 8/40 |  Train Loss: 2.3485 |  Val Loss: 2.3071 |  Train Acc: 0.110 |  Val Acc: 0.115
# Early Stopping Counter: 2/20
# Epoch 9/40 |  Train Loss: 2.3340 |  Val Loss: 2.3052 |  Train Acc: 0.114 |  Val Acc: 0.129
# Early Stopping Counter: 3/20
# Epoch 10/40 |  Train Loss: 2.3362 |  Val Loss: 2.3014 |  Train Acc: 0.116 |  Val Acc: 0.115
# Early Stopping Counter: 4/20
# Epoch 11/40 |  Train Loss: 2.3242 |  Val Loss: 2.3015 |  Train Acc: 0.117 |  Val Acc: 0.121
# Early Stopping Counter: 5/20
# Epoch 12/40 |  Train Loss: 2.3231 |  Val Loss: 2.3020 |  Train Acc: 0.117 |  Val Acc: 0.156
# Epoch 13/40 |  Train Loss: 2.3252 |  Val Loss: 2.3144 |  Train Acc: 0.117 |  Val Acc: 0.117
# Early Stopping Counter: 1/20
# Epoch 14/40 |  Train Loss: 2.3195 |  Val Loss: 2.3089 |  Train Acc: 0.117 |  Val Acc: 0.117
# Early Stopping Counter: 2/20
# Epoch 15/40 |  Train Loss: 2.3038 |  Val Loss: 2.3098 |  Train Acc: 0.132 |  Val Acc: 0.102
# Early Stopping Counter: 3/20
# Epoch 16/40 |  Train Loss: 2.3084 |  Val Loss: 2.3108 |  Train Acc: 0.130 |  Val Acc: 0.140
# Early Stopping Counter: 4/20
# Epoch 17/40 |  Train Loss: 2.3071 |  Val Loss: 2.2988 |  Train Acc: 0.126 |  Val Acc: 0.131
# Early Stopping Counter: 5/20
# Epoch 18/40 |  Train Loss: 2.3088 |  Val Loss: 2.2964 |  Train Acc: 0.127 |  Val Acc: 0.121
# Early Stopping Counter: 6/20
# Epoch 19/40 |  Train Loss: 2.3065 |  Val Loss: 2.2989 |  Train Acc: 0.128 |  Val Acc: 0.108
# Early Stopping Counter: 7/20
# Epoch 20/40 |  Train Loss: 2.2986 |  Val Loss: 2.2982 |  Train Acc: 0.133 |  Val Acc: 0.110
# Early Stopping Counter: 8/20
# Epoch 21/40 |  Train Loss: 2.2960 |  Val Loss: 2.3110 |  Train Acc: 0.137 |  Val Acc: 0.102
# Early Stopping Counter: 9/20
# Epoch 22/40 |  Train Loss: 2.2968 |  Val Loss: 2.3098 |  Train Acc: 0.135 |  Val Acc: 0.117
# Early Stopping Counter: 10/20
# Epoch 23/40 |  Train Loss: 2.2920 |  Val Loss: 2.3172 |  Train Acc: 0.146 |  Val Acc: 0.113
# Early Stopping Counter: 11/20
# Epoch 24/40 |  Train Loss: 2.2862 |  Val Loss: 2.3081 |  Train Acc: 0.141 |  Val Acc: 0.106
# Early Stopping Counter: 12/20
# Epoch 25/40 |  Train Loss: 2.2862 |  Val Loss: 2.3093 |  Train Acc: 0.140 |  Val Acc: 0.117
# Early Stopping Counter: 13/20
# Epoch 26/40 |  Train Loss: 2.2818 |  Val Loss: 2.3089 |  Train Acc: 0.143 |  Val Acc: 0.115
# Early Stopping Counter: 14/20
# Epoch 27/40 |  Train Loss: 2.2854 |  Val Loss: 2.3021 |  Train Acc: 0.135 |  Val Acc: 0.121
# Early Stopping Counter: 15/20
# Epoch 28/40 |  Train Loss: 2.2781 |  Val Loss: 2.3033 |  Train Acc: 0.143 |  Val Acc: 0.117
# Early Stopping Counter: 16/20
# Epoch 29/40 |  Train Loss: 2.2717 |  Val Loss: 2.3149 |  Train Acc: 0.144 |  Val Acc: 0.115
# Early Stopping Counter: 17/20
# Epoch 30/40 |  Train Loss: 2.2718 |  Val Loss: 2.3036 |  Train Acc: 0.153 |  Val Acc: 0.123
# Early Stopping Counter: 18/20
# Epoch 31/40 |  Train Loss: 2.2737 |  Val Loss: 2.3085 |  Train Acc: 0.152 |  Val Acc: 0.110
# Early Stopping Counter: 19/20
# Epoch 32/40 |  Train Loss: 2.2645 |  Val Loss: 2.3195 |  Train Acc: 0.150 |  Val Acc: 0.119
# Early Stopping Counter: 20/20
# Early stopping triggered at epoch 32
# Fold 15 Validation Accuracy: 0.1562
#
#
#
# Mean Accuracy: 0.1417 ± 0.0149

# %%
# def objective(trial):
#     t0 = trial.suggest_float("time_window_t0", 0.0, 0.25)
#     t1 = trial.suggest_float("time_window_t1", 0.5, 0.85)
    
#     dataset_params  = {
#         'time_window'  : (t0, t1), 
#         'grid_size'    : trial.suggest_categorical("grid_size", [32, 48, 56, 64, 72]), 
#         'n_time_slices': trial.suggest_categorical("n_time_slices", [8, 12, 16, 32, 48])
#     }

#     model_params = {
#         'in_channels'       :dataset_params["n_time_slices"], 
#         'hidden_channels'   :trial.suggest_int("hidden_channels", dataset_params["n_time_slices"], 4*dataset_params["n_time_slices"]),
#         'conv_dropout'      :trial.suggest_float("conv_dropout", 0.1, 0.5),
#         'classifier_dropout':trial.suggest_float("classifier_dropout", 0.1, 0.5),
#         'conv_activation'   :trial.suggest_categorical("conv_activation", ["relu", "silu", "gelu"]),
#     }
#     model_params["reduction"] = trial.suggest_int("reduction", 8, model_params["hidden_channels"])
    
#     training_params = {
#         'lr':trial.suggest_float("lr", .0001, .01, log=True), 
#         "weight_decay":trial.suggest_float("weight_decay", .0001, .01, log=True)
#     }
    
#     cv_scores, mean_acc, std_acc = cross_validate(
#         '/kaggle/input/the-imagine-decoding-challenge/train/train', 
#         n_splits=3, 
#         dataset_params=dataset_params,
#         model_params=model_params,
#         training_params=training_params,
#         device='cuda'
#     )
#     return mean_acc,std_acc

# study = optuna.create_study(directions=["maximize", "minimize"])  
# study.optimize(objective, n_trials=25)
